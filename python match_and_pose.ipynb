# %%
import os
import cv2
import csv
import numpy as np

# --- PARAMETERS ---
IMG_DIR   = '.'  # folder with your dino*.png
GOOD_FILE = 'dino_good_silhouette_images.txt'
ANG_FILE  = 'dino_ang.txt'
PAR_FILE  = 'dino_par.txt'

RATIO_THR   = 0.7   # Lowe’s ratio test threshold
RANSAC_THR  = 1.0   # RANSAC reprojection threshold (pixels)
MIN_MATCHES = 8     # minimum matches after ratio test

# --- 1. Load good‐silhouette list ---
with open(GOOD_FILE, 'r') as f:
    good_imgs = {ln.strip() for ln in f if ln.strip()}

# --- 2. Load angles and keep only good images ---
ang_map = {}
with open(ANG_FILE, 'r') as f:
    for ln in f:
        parts = ln.strip().split()
        if len(parts) != 3:
            continue
        try:
            lat, lon = float(parts[0]), float(parts[1])
        except ValueError:
            continue
        name = parts[2]
        if name in good_imgs:
            ang_map[name] = (lat, lon)

# sort by latitude, then longitude
sorted_imgs = sorted(ang_map.keys(), key=lambda n: (ang_map[n][0], ang_map[n][1]))

# --- 3. Parse calibration file to extract K ---
K = None
with open(PAR_FILE, 'r') as f:
    for ln in f:
        parts = ln.strip().split()
        # each line: "dino0001.png fx cx  fy cy  ...", adjust as needed
        if len(parts) >= 7 and parts[0].endswith('.png'):
            fx, cx = float(parts[1]), float(parts[3])
            fy, cy = float(parts[5]), float(parts[6])
            K = np.array([[fx,   0, cx],
                          [  0, fy, cy],
                          [  0,   0,  1]])
            break
if K is None:
    raise RuntimeError(f"Could not parse intrinsics from {PAR_FILE}")

# prepare SIFT and BFMatcher
sift = cv2.SIFT_create()
bf   = cv2.BFMatcher(cv2.NORM_L2)

# make output folders
os.makedirs('matches', exist_ok=True)

# CSV log
with open('pair_results.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img1','img2','raw_matches','inliers','t_x','t_y','t_z'])

    # --- 4. Loop over consecutive pairs ---
    for i in range(len(sorted_imgs) - 1):
        img1_name = sorted_imgs[i]
        img2_name = sorted_imgs[i+1]

        # load grayscale
        img1 = cv2.imread(os.path.join(IMG_DIR, img1_name), cv2.IMREAD_GRAYSCALE)
        img2 = cv2.imread(os.path.join(IMG_DIR, img2_name), cv2.IMREAD_GRAYSCALE)
        if img1 is None or img2 is None:
            print(f"Warning: couldn’t load {img1_name} or {img2_name}, skipping")
            continue

        # detect & describe
        kp1, des1 = sift.detectAndCompute(img1, None)
        kp2, des2 = sift.detectAndCompute(img2, None)

        # raw knn matches + Lowe’s ratio test
        raw = bf.knnMatch(des1, des2, k=2)
        good = []
        pts1, pts2 = [], []
        for m, n in raw:
            if m.distance < RATIO_THR * n.distance:
                good.append(m)
                pts1.append(kp1[m.queryIdx].pt)
                pts2.append(kp2[m.trainIdx].pt)

        pts1 = np.float32(pts1)
        pts2 = np.float32(pts2)
        raw_count = len(good)
        if raw_count < MIN_MATCHES:
            print(f"{img1_name}–{img2_name}: only {raw_count} after ratio test; skipping")
            continue

        # estimate Fundamental matrix via RANSAC
        F, mask = cv2.findFundamentalMat(pts1, pts2,
                                         cv2.FM_RANSAC,
                                         ransacReprojThreshold=RANSAC_THR,
                                         confidence=0.99)
        if F is None:
            print(f"{img1_name}–{img2_name}: Fundamental matrix failed; skipping")
            continue

        inlier_mask = mask.ravel().astype(bool)
        inlier_count = int(inlier_mask.sum())

        # --- 5. Compute Essential & recover pose ---
        E = K.T @ F @ K
        pts1_in = pts1[inlier_mask]
        pts2_in = pts2[inlier_mask]
        _, R, t, _ = cv2.recoverPose(E, pts1_in, pts2_in, K)

        # --- 6. Draw & save inlier matches ---
        mask_ints = [int(m) for m in inlier_mask]  # cv2 wants ints, not bools
        vis = cv2.drawMatches(
            img1, kp1, img2, kp2, good, None,
            matchColor=(0,255,0),
            singlePointColor=None,
            matchesMask=mask_ints,
            flags=cv2.DrawMatchesFlags_DEFAULT,
            matchesThickness=1
        )
        out_fn = f"matches/{img1_name[:-4]}_{img2_name[:-4]}_inliers.png"
        cv2.imwrite(out_fn, vis)

        # log to CSV
        tx, ty, tz = t.ravel()
        writer.writerow([img1_name, img2_name,
                         raw_count, inlier_count,
                         tx, ty, tz])

        print(f"{img1_name}–{img2_name}: {inlier_count}/{raw_count} inliers, t = [{tx:.3f}, {ty:.3f}, {tz:.3f}]")

print("Done.  Inlier visuals in ‘matches/’, summary in ‘pair_results.csv’.")
# Out:
# dino0049.png–dino0048.png: 61/83 inliers, t = [0.020, -0.471, -0.882]
# dino0048.png–dino0047.png: 54/82 inliers, t = [0.059, -0.864, 0.500]
# dino0047.png–dino0046.png: 45/77 inliers, t = [-0.005, -0.534, -0.846]
# dino0046.png–dino0045.png: 34/55 inliers, t = [0.035, -0.339, 0.940]
# dino0045.png–dino0044.png: 25/45 inliers, t = [0.048, 0.091, 0.995]
# dino0044.png–dino0043.png: 21/33 inliers, t = [-0.064, 0.381, 0.922]
# dino0043.png–dino0042.png: 13/22 inliers, t = [-0.002, -0.036, 0.999]
# dino0042.png–dino0041.png: 14/20 inliers, t = [-0.050, 0.039, 0.998]
# dino0041.png–dino0040.png: 14/23 inliers, t = [0.064, -0.224, -0.972]
# dino0040.png–dino0039.png: 21/34 inliers, t = [0.041, -0.464, -0.885]
# dino0039.png–dino0038.png: 26/47 inliers, t = [0.032, -0.220, -0.975]
# dino0038.png–dino0037.png: 45/74 inliers, t = [0.020, -0.414, -0.910]
# dino0037.png–dino0036.png: 53/81 inliers, t = [0.024, -0.326, -0.945]
# dino0036.png–dino0035.png: 71/104 inliers, t = [0.019, -0.433, -0.901]
# dino0035.png–dino0034.png: 69/103 inliers, t = [0.032, 0.319, -0.947]
# dino0034.png–dino0033.png: 103/125 inliers, t = [0.006, -0.457, 0.889]
# dino0033.png–dino0032.png: 99/138 inliers, t = [0.040, -0.225, -0.974]
# dino0032.png–dino0031.png: 110/137 inliers, t = [-0.032, -0.351, 0.936]
# dino0031.png–dino0030.png: 131/161 inliers, t = [0.013, -0.911, -0.413]
# dino0030.png–dino0006.png: only 5 after ratio test; skipping
# dino0006.png–dino0005.png: 70/103 inliers, t = [0.111, -0.891, -0.439]
# dino0005.png–dino0004.png: 73/92 inliers, t = [0.021, -0.991, -0.134]
# dino0004.png–dino0003.png: 76/97 inliers, t = [-0.039, -0.968, -0.249]
# dino0003.png–dino0002.png: 68/86 inliers, t = [-0.018, -0.575, -0.818]
# dino0002.png–dino0001.png: 89/103 inliers, t = [-0.001, 0.495, 0.869]
# dino0001.png–dino0050.png: 50/75 inliers, t = [-0.302, 0.263, 0.916]
# dino0050.png–dino0051.png: 49/73 inliers, t = [0.025, -0.319, 0.947]
# dino0051.png–dino0052.png: 40/68 inliers, t = [0.025, 0.426, 0.904]
# dino0052.png–dino0053.png: 38/70 inliers, t = [0.065, 0.462, 0.884]
# dino0053.png–dino0054.png: 28/49 inliers, t = [-0.064, -0.270, 0.961]
# dino0054.png–dino0055.png: 22/39 inliers, t = [0.004, -0.110, 0.994]
# dino0055.png–dino0056.png: 22/34 inliers, t = [0.012, -0.069, 0.998]
# dino0056.png–dino0057.png: 16/23 inliers, t = [-0.009, -0.042, 0.999]
# dino0057.png–dino0058.png: 13/18 inliers, t = [-0.023, -0.046, 0.999]
# dino0058.png–dino0059.png: 15/23 inliers, t = [0.039, -0.018, -0.999]
# dino0059.png–dino0060.png: 22/41 inliers, t = [0.014, 0.390, -0.921]
# dino0060.png–dino0061.png: 30/52 inliers, t = [0.016, -0.711, -0.703]
# dino0061.png–dino0062.png: 55/84 inliers, t = [0.020, 0.493, -0.870]
# dino0062.png–dino0063.png: 72/105 inliers, t = [0.061, -0.750, -0.659]
# dino0063.png–dino0064.png: 72/97 inliers, t = [0.035, 0.994, -0.107]
# dino0064.png–dino0065.png: 48/76 inliers, t = [0.050, -0.443, -0.895]
# dino0065.png–dino0066.png: 100/139 inliers, t = [0.017, 0.297, -0.955]
# dino0066.png–dino0067.png: 102/139 inliers, t = [0.034, 0.186, -0.982]
# dino0067.png–dino0068.png: 121/149 inliers, t = [0.104, -0.917, 0.385]
# dino0068.png–dino0069.png: 129/147 inliers, t = [-0.039, -0.597, 0.801]
# dino0069.png–dino0070.png: 134/155 inliers, t = [-0.013, -0.369, -0.929]
# dino0070.png–dino0071.png: 108/144 inliers, t = [-0.038, -0.885, -0.464]
# dino0071.png–dino0072.png: 111/139 inliers, t = [-0.090, -0.992, -0.092]
# dino0072.png–dino0073.png: 115/143 inliers, t = [-0.013, -0.286, -0.958]
# dino0073.png–dino0074.png: 109/149 inliers, t = [0.018, 0.229, 0.973]
# dino0074.png–dino0075.png: 106/133 inliers, t = [0.157, -0.956, 0.250]
# dino0075.png–dino0090.png: only 3 after ratio test; skipping
# dino0090.png–dino0091.png: 79/113 inliers, t = [0.051, -0.068, -0.996]
# dino0091.png–dino0092.png: 73/99 inliers, t = [0.009, -0.559, -0.829]
# dino0092.png–dino0093.png: 70/93 inliers, t = [0.027, -0.278, -0.960]
# dino0093.png–dino0094.png: 63/88 inliers, t = [-0.006, -0.493, 0.870]
# dino0094.png–dino0095.png: 62/87 inliers, t = [-0.077, -0.776, 0.626]
# dino0095.png–dino0096.png: 60/87 inliers, t = [-0.019, -0.206, -0.978]
# dino0096.png–dino0097.png: 68/93 inliers, t = [0.006, 0.635, -0.773]
# dino0097.png–dino0145.png: 44/67 inliers, t = [-0.808, 0.560, 0.181]
# dino0145.png–dino0144.png: 51/71 inliers, t = [-0.035, -0.302, -0.953]
# dino0144.png–dino0143.png: 38/63 inliers, t = [-0.009, -0.303, 0.953]
# dino0143.png–dino0142.png: 31/51 inliers, t = [-0.200, -0.698, 0.687]
# dino0142.png–dino0141.png: 25/38 inliers, t = [-0.023, -0.209, 0.978]
# dino0141.png–dino0140.png: 20/40 inliers, t = [-0.004, -0.130, 0.992]
# dino0140.png–dino0139.png: 16/26 inliers, t = [-0.454, 0.383, -0.804]
# dino0139.png–dino0138.png: 13/17 inliers, t = [-0.022, -0.007, 1.000]
# dino0138.png–dino0137.png: 15/23 inliers, t = [0.001, 0.278, -0.961]
# dino0137.png–dino0136.png: 21/31 inliers, t = [-0.001, -0.992, -0.124]
# dino0136.png–dino0135.png: 24/42 inliers, t = [-0.004, -0.161, -0.987]
# dino0135.png–dino0134.png: 47/70 inliers, t = [-0.005, -0.380, -0.925]
# dino0134.png–dino0133.png: 62/99 inliers, t = [-0.020, -0.502, -0.865]
# dino0133.png–dino0132.png: 69/107 inliers, t = [0.017, 0.274, -0.961]
# dino0132.png–dino0131.png: 71/107 inliers, t = [-0.019, -0.307, -0.952]
# dino0131.png–dino0130.png: 91/132 inliers, t = [0.046, -0.832, -0.554]
# dino0130.png–dino0129.png: 107/133 inliers, t = [0.075, -0.930, -0.360]
# dino0129.png–dino0128.png: 103/140 inliers, t = [0.039, -0.188, -0.981]
# dino0128.png–dino0127.png: 104/144 inliers, t = [0.023, 0.047, -0.999]
# dino0127.png–dino0126.png: 138/161 inliers, t = [0.044, -0.830, 0.556]
# dino0126.png–dino0125.png: 109/146 inliers, t = [0.006, -0.284, 0.959]
# dino0125.png–dino0124.png: 108/144 inliers, t = [0.013, -0.170, -0.985]
# dino0124.png–dino0123.png: 127/150 inliers, t = [-0.097, -0.992, -0.086]
# dino0123.png–dino0122.png: 109/136 inliers, t = [0.002, -0.331, -0.944]
# dino0122.png–dino0121.png: 105/132 inliers, t = [-0.027, 0.617, 0.787]
# dino0121.png–dino0120.png: 101/126 inliers, t = [-0.054, 0.399, 0.915]
# dino0120.png–dino0119.png: 79/112 inliers, t = [-0.024, -0.478, 0.878]
# dino0119.png–dino0118.png: 70/97 inliers, t = [-0.012, -1.000, 0.026]
# dino0118.png–dino0117.png: 43/66 inliers, t = [0.007, 0.873, 0.487]
# dino0117.png–dino0116.png: 25/43 inliers, t = [0.071, 0.896, 0.439]
# dino0116.png–dino0112.png: only 4 after ratio test; skipping
# dino0112.png–dino0111.png: 32/54 inliers, t = [0.203, 0.978, 0.037]
# dino0111.png–dino0110.png: 47/68 inliers, t = [0.067, 0.379, -0.923]
# dino0110.png–dino0109.png: 62/82 inliers, t = [-0.022, -0.620, -0.784]
# dino0109.png–dino0106.png: 30/46 inliers, t = [0.143, -0.883, 0.447]
# dino0106.png–dino0105.png: 74/102 inliers, t = [0.051, -0.686, 0.726]
# dino0105.png–dino0104.png: 76/109 inliers, t = [0.038, -0.128, -0.991]
# dino0104.png–dino0103.png: 66/98 inliers, t = [0.007, 0.639, 0.769]
# dino0103.png–dino0102.png: 74/100 inliers, t = [-0.091, -0.768, -0.634]
# dino0102.png–dino0101.png: 59/79 inliers, t = [0.000, 0.472, -0.882]
# dino0101.png–dino0100.png: 60/91 inliers, t = [0.029, 0.391, 0.920]
# dino0100.png–dino0099.png: 55/87 inliers, t = [0.044, -0.499, 0.866]
# dino0099.png–dino0098.png: 63/93 inliers, t = [-0.002, 0.056, 0.998]
# dino0098.png–dino0146.png: 43/62 inliers, t = [0.791, -0.534, -0.300]
# dino0146.png–dino0147.png: 47/66 inliers, t = [-0.008, 0.296, 0.955]
# dino0147.png–dino0148.png: 33/56 inliers, t = [0.011, -0.159, 0.987]
# dino0148.png–dino0149.png: 32/48 inliers, t = [-0.034, -0.372, 0.928]
# dino0149.png–dino0150.png: 12/21 inliers, t = [0.087, -0.014, 0.996]
# dino0150.png–dino0151.png: 14/20 inliers, t = [0.217, -0.012, 0.976]
# dino0151.png–dino0152.png: 12/16 inliers, t = [0.001, 0.099, 0.995]
# dino0152.png–dino0157.png: only 5 after ratio test; skipping
# dino0157.png–dino0158.png: 116/136 inliers, t = [0.031, -0.891, -0.454]
# dino0158.png–dino0159.png: 109/135 inliers, t = [-0.123, -0.987, -0.107]
# dino0159.png–dino0160.png: 94/124 inliers, t = [0.046, 0.438, 0.898]
# dino0160.png–dino0161.png: 95/121 inliers, t = [0.050, -0.424, -0.904]
# dino0161.png–dino0162.png: only 2 after ratio test; skipping
# dino0162.png–dino0163.png: 15/22 inliers, t = [-0.035, -0.994, -0.107]
# dino0163.png–dino0164.png: 23/30 inliers, t = [0.140, -0.787, 0.601]
# dino0164.png–dino0165.png: 32/48 inliers, t = [0.018, -0.312, 0.950]
# dino0165.png–dino0166.png: 43/66 inliers, t = [0.034, -0.211, -0.977]
# dino0166.png–dino0167.png: 58/83 inliers, t = [0.086, -0.335, -0.938]
# dino0167.png–dino0168.png: 62/93 inliers, t = [0.257, -0.828, -0.498]
# dino0168.png–dino0169.png: 62/87 inliers, t = [0.083, -0.367, 0.926]
# dino0169.png–dino0170.png: 70/90 inliers, t = [-0.012, -0.252, -0.968]
# dino0170.png–dino0171.png: 61/98 inliers, t = [0.136, -0.663, -0.736]
# dino0171.png–dino0172.png: 67/96 inliers, t = [-0.128, -0.986, 0.104]
# dino0172.png–dino0173.png: 56/85 inliers, t = [-0.012, 0.264, 0.965]
# dino0173.png–dino0174.png: 59/77 inliers, t = [0.035, -0.511, -0.859]
# dino0174.png–dino0175.png: 54/78 inliers, t = [0.056, -0.956, 0.287]
# dino0175.png–dino0176.png: 57/86 inliers, t = [-0.022, 0.460, 0.888]
# dino0176.png–dino0177.png: 67/85 inliers, t = [-0.044, -0.460, -0.887]
# dino0177.png–dino0196.png: 13/22 inliers, t = [0.551, -0.110, -0.827]
# dino0196.png–dino0195.png: 8/12 inliers, t = [0.175, -0.150, -0.973]
# dino0195.png–dino0194.png: only 1 after ratio test; skipping
# dino0194.png–dino0193.png: 91/135 inliers, t = [0.031, -0.092, -0.995]
# dino0193.png–dino0192.png: 65/95 inliers, t = [-0.004, -0.254, -0.967]
# dino0192.png–dino0191.png: 106/141 inliers, t = [0.126, -0.750, 0.649]
# dino0191.png–dino0190.png: 117/140 inliers, t = [0.048, -0.334, -0.941]
# dino0190.png–dino0189.png: 119/142 inliers, t = [0.100, -0.937, -0.335]
# dino0189.png–dino0188.png: 109/135 inliers, t = [0.001, -0.253, 0.968]
# dino0188.png–dino0187.png: only 3 after ratio test; skipping
# dino0187.png–dino0186.png: 16/22 inliers, t = [0.025, -0.102, -0.994]
# dino0186.png–dino0185.png: 15/25 inliers, t = [0.112, -0.380, 0.918]
# dino0185.png–dino0184.png: 23/39 inliers, t = [0.045, -0.286, -0.957]
# dino0184.png–dino0183.png: 35/50 inliers, t = [0.031, -0.380, -0.924]
# dino0183.png–dino0182.png: 52/79 inliers, t = [0.043, -0.284, -0.958]
# dino0182.png–dino0181.png: 56/77 inliers, t = [0.061, -0.147, -0.987]
# dino0181.png–dino0180.png: 54/80 inliers, t = [0.103, -0.170, -0.980]
# dino0180.png–dino0179.png: 56/93 inliers, t = [0.042, 0.168, 0.985]
# dino0179.png–dino0178.png: 62/90 inliers, t = [0.043, 0.389, -0.920]
# dino0178.png–dino0197.png: 7/9 inliers, t = [-0.045, 0.133, 0.990]
# dino0197.png–dino0198.png: 27/38 inliers, t = [0.075, -0.516, 0.853]
# dino0198.png–dino0199.png: 19/34 inliers, t = [-0.012, -0.635, 0.772]
# dino0199.png–dino0200.png: 13/21 inliers, t = [-0.035, -0.038, 0.999]
# dino0200.png–dino0201.png: only 0 after ratio test; skipping
# dino0201.png–dino0202.png: 70/108 inliers, t = [0.017, -0.264, -0.964]
# dino0202.png–dino0203.png: 87/115 inliers, t = [0.050, -0.992, 0.112]
# dino0203.png–dino0204.png: 93/129 inliers, t = [-0.047, -0.408, -0.912]
# dino0204.png–dino0205.png: 113/132 inliers, t = [0.008, -0.480, 0.877]
# dino0205.png–dino0206.png: 115/143 inliers, t = [-0.090, -0.496, 0.864]
# dino0206.png–dino0207.png: 121/141 inliers, t = [0.031, -0.494, -0.869]
# dino0207.png–dino0208.png: 112/134 inliers, t = [0.066, -0.561, 0.825]
# dino0208.png–dino0209.png: only 5 after ratio test; skipping
# dino0209.png–dino0210.png: 29/38 inliers, t = [-0.032, -0.209, 0.977]
# dino0210.png–dino0211.png: 18/33 inliers, t = [0.087, -0.437, 0.895]
# dino0211.png–dino0212.png: 14/25 inliers, t = [0.034, -0.048, 0.998]
# dino0212.png–dino0213.png: 21/35 inliers, t = [-0.033, -0.677, 0.735]
# dino0213.png–dino0214.png: 20/32 inliers, t = [0.018, -0.772, 0.635]
# dino0214.png–dino0215.png: 28/44 inliers, t = [0.039, -0.942, 0.334]
# dino0215.png–dino0216.png: 43/64 inliers, t = [0.276, -0.775, -0.568]
# dino0216.png–dino0217.png: 40/68 inliers, t = [-0.007, -0.775, -0.632]
# dino0217.png–dino0218.png: 41/73 inliers, t = [-0.012, 0.282, 0.959]
# dino0218.png–dino0242.png: 7/8 inliers, t = [0.177, -0.430, 0.885]
# dino0242.png–dino0241.png: 25/40 inliers, t = [0.028, -0.498, 0.867]
# dino0241.png–dino0240.png: 7/11 inliers, t = [0.311, 0.558, -0.770]
# dino0240.png–dino0239.png: only 2 after ratio test; skipping
# dino0239.png–dino0238.png: 53/82 inliers, t = [0.075, -0.972, -0.225]
# dino0238.png–dino0237.png: 65/98 inliers, t = [-0.011, 0.226, -0.974]
# dino0237.png–dino0236.png: 89/117 inliers, t = [0.046, -0.386, -0.921]
# dino0236.png–dino0235.png: 82/122 inliers, t = [0.058, -0.525, -0.849]
# dino0235.png–dino0234.png: 91/132 inliers, t = [0.141, -0.925, 0.353]
# dino0234.png–dino0233.png: 112/141 inliers, t = [0.103, -0.805, 0.584]
# dino0233.png–dino0232.png: 100/132 inliers, t = [0.009, -0.161, 0.987]
# dino0232.png–dino0231.png: 24/35 inliers, t = [0.180, -0.768, -0.615]
# dino0231.png–dino0230.png: 60/86 inliers, t = [-0.049, -0.586, -0.809]
# dino0230.png–dino0229.png: 45/75 inliers, t = [-0.053, -0.376, 0.925]
# dino0229.png–dino0228.png: 28/50 inliers, t = [-0.036, 0.252, 0.967]
# dino0228.png–dino0227.png: 16/28 inliers, t = [-0.012, 0.097, 0.995]
# dino0227.png–dino0226.png: 19/30 inliers, t = [-0.059, -0.376, 0.925]
# dino0226.png–dino0225.png: 19/35 inliers, t = [-0.017, 0.927, 0.375]
# dino0225.png–dino0224.png: 32/46 inliers, t = [0.049, -0.593, -0.804]
# dino0224.png–dino0223.png: 30/47 inliers, t = [-0.018, -0.330, -0.944]
# dino0223.png–dino0221.png: only 3 after ratio test; skipping
# dino0221.png–dino0220.png: 36/54 inliers, t = [0.007, -0.436, 0.900]
# dino0220.png–dino0219.png: 55/74 inliers, t = [0.029, -0.412, -0.911]
# dino0219.png–dino0243.png: 25/40 inliers, t = [-0.450, 0.195, 0.871]
# dino0243.png–dino0244.png: 26/35 inliers, t = [-0.021, 0.230, 0.973]
# dino0244.png–dino0245.png: 21/30 inliers, t = [-0.044, -0.185, 0.982]
# dino0245.png–dino0246.png: only 3 after ratio test; skipping
# dino0246.png–dino0247.png: 31/57 inliers, t = [0.009, 0.213, -0.977]
# dino0247.png–dino0248.png: 40/61 inliers, t = [-0.039, 0.268, -0.963]
# dino0248.png–dino0249.png: 75/101 inliers, t = [0.034, -0.288, -0.957]
# dino0249.png–dino0250.png: 94/128 inliers, t = [0.071, -0.529, -0.846]
# dino0250.png–dino0251.png: 82/123 inliers, t = [0.038, -0.151, -0.988]
# dino0251.png–dino0252.png: 112/141 inliers, t = [0.047, -0.295, -0.954]
# dino0252.png–dino0253.png: 44/61 inliers, t = [0.128, -0.743, 0.657]
# dino0253.png–dino0254.png: 85/115 inliers, t = [-0.044, 0.207, 0.977]
# dino0254.png–dino0255.png: 68/101 inliers, t = [-0.040, -0.611, 0.791]
# dino0255.png–dino0256.png: 44/66 inliers, t = [-0.025, -0.336, -0.942]
# dino0256.png–dino0257.png: 31/51 inliers, t = [-0.009, -0.322, 0.947]
# dino0257.png–dino0258.png: 25/39 inliers, t = [-0.034, 0.194, 0.980]
# dino0258.png–dino0259.png: 20/33 inliers, t = [-0.029, 0.098, 0.995]
# dino0259.png–dino0260.png: 25/36 inliers, t = [0.072, -0.937, -0.341]
# dino0260.png–dino0261.png: 31/46 inliers, t = [0.080, -0.957, -0.279]
# dino0261.png–dino0262.png: 8/13 inliers, t = [0.036, 0.133, -0.991]
# dino0262.png–dino0263.png: 41/58 inliers, t = [0.120, -0.639, 0.760]
# dino0263.png–dino0264.png: 23/39 inliers, t = [0.009, -0.062, -0.998]
# dino0264.png–dino0265.png: 48/69 inliers, t = [0.023, -0.060, -0.998]
# dino0265.png–dino0286.png: 21/32 inliers, t = [0.716, -0.374, 0.589]
# dino0286.png–dino0285.png: 21/34 inliers, t = [-0.041, 0.216, 0.976]
# dino0285.png–dino0284.png: 15/23 inliers, t = [-0.005, 0.134, 0.991]
# dino0284.png–dino0283.png: 11/19 inliers, t = [0.833, 0.222, 0.507]
# dino0283.png–dino0282.png: 37/57 inliers, t = [-0.074, 0.582, -0.810]
# dino0282.png–dino0281.png: 48/74 inliers, t = [-0.055, 0.308, -0.950]
# dino0281.png–dino0280.png: 77/117 inliers, t = [0.034, -0.147, -0.989]
# dino0280.png–dino0279.png: 80/113 inliers, t = [-0.048, -0.426, -0.903]
# dino0279.png–dino0278.png: 95/131 inliers, t = [0.045, -0.213, 0.976]
# dino0278.png–dino0277.png: 60/84 inliers, t = [0.174, -0.613, 0.771]
# dino0277.png–dino0276.png: 88/107 inliers, t = [0.182, -0.948, -0.262]
# dino0276.png–dino0275.png: 74/100 inliers, t = [0.152, -0.988, 0.030]
# dino0275.png–dino0274.png: 49/71 inliers, t = [-0.004, -0.218, 0.976]
# dino0274.png–dino0273.png: 39/53 inliers, t = [-0.219, 0.758, 0.614]
# dino0273.png–dino0272.png: 25/40 inliers, t = [-0.075, 0.697, -0.713]
# dino0272.png–dino0271.png: 20/34 inliers, t = [0.141, -0.982, 0.125]
# dino0271.png–dino0270.png: 21/35 inliers, t = [0.060, -0.690, 0.721]
# dino0270.png–dino0269.png: 8/11 inliers, t = [-0.010, 0.087, -0.996]
# dino0269.png–dino0268.png: 20/31 inliers, t = [-0.036, 0.208, -0.978]
# dino0268.png–dino0266.png: 21/30 inliers, t = [0.106, -0.429, 0.897]
# dino0266.png–dino0287.png: 25/30 inliers, t = [-0.583, 0.186, 0.791]
# dino0287.png–dino0288.png: 33/46 inliers, t = [0.124, -0.720, 0.683]
# dino0288.png–dino0289.png: 14/17 inliers, t = [-0.054, 0.083, -0.995]
# dino0289.png–dino0290.png: 35/56 inliers, t = [0.151, -0.798, -0.583]
# dino0290.png–dino0291.png: 61/82 inliers, t = [-0.194, 0.976, -0.096]
# dino0291.png–dino0292.png: 93/109 inliers, t = [-0.052, 0.317, -0.947]
# dino0292.png–dino0293.png: 51/71 inliers, t = [0.064, -0.340, 0.938]
# dino0293.png–dino0294.png: 82/106 inliers, t = [0.014, -0.262, 0.965]
# dino0294.png–dino0295.png: 54/75 inliers, t = [-0.013, 0.122, 0.992]
# dino0295.png–dino0296.png: 44/55 inliers, t = [-0.147, 0.470, 0.870]
# dino0296.png–dino0297.png: 25/38 inliers, t = [0.054, -0.382, 0.922]
# dino0297.png–dino0298.png: 14/22 inliers, t = [-0.025, 0.016, 1.000]
# dino0298.png–dino0299.png: 29/38 inliers, t = [-0.082, 0.406, 0.910]
# dino0299.png–dino0300.png: 21/33 inliers, t = [-0.229, 0.652, -0.722]
# dino0300.png–dino0301.png: 67/86 inliers, t = [0.019, -0.280, 0.960]
# dino0301.png–dino0310.png: 24/38 inliers, t = [-0.947, 0.213, 0.240]
# dino0310.png–dino0309.png: 15/19 inliers, t = [0.604, -0.678, 0.418]
# dino0309.png–dino0308.png: 36/53 inliers, t = [-0.158, 0.299, -0.941]
# dino0308.png–dino0307.png: 25/35 inliers, t = [0.195, -0.296, -0.935]
# dino0307.png–dino0306.png: 41/63 inliers, t = [-0.100, 0.198, 0.975]
# dino0306.png–dino0305.png: 30/47 inliers, t = [0.055, -0.179, 0.982]
# dino0305.png–dino0304.png: 23/32 inliers, t = [-0.073, 0.234, 0.970]
# dino0304.png–dino0303.png: 23/31 inliers, t = [0.039, -0.154, -0.987]
# dino0303.png–dino0302.png: 98/103 inliers, t = [-0.032, 0.190, -0.981]
# dino0302.png–dino0311.png: 28/40 inliers, t = [-0.137, 0.031, -0.990]
# dino0311.png–dino0312.png: 36/47 inliers, t = [-0.449, 0.368, -0.814]
# dino0312.png–dino0313.png: 43/62 inliers, t = [-0.118, 0.062, 0.991]
# dino0313.png–dino0314.png: 36/54 inliers, t = [0.353, -0.236, 0.905]
# dino0314.png–dino0315.png: 108/116 inliers, t = [0.071, -0.050, 0.996]
# dino0315.png–dino0316.png: 16/24 inliers, t = [0.571, 0.010, -0.821]
# dino0316.png–dino0317.png: 14/22 inliers, t = [0.051, 0.013, -0.999]
# dino0317.png–dino0320.png: 12/15 inliers, t = [-0.078, -0.042, -0.996]
# dino0320.png–dino0319.png: only 7 after ratio test; skipping
# dino0319.png–dino0318.png: 7/8 inliers, t = [0.007, 0.076, 0.997]
# dino0318.png–dino0321.png: 7/8 inliers, t = [-0.055, 0.044, 0.998]
# dino0321.png–dino0322.png: 7/10 inliers, t = [0.566, 0.514, -0.644]
# dino0322.png–dino0326.png: only 1 after ratio test; skipping
# dino0326.png–dino0325.png: only 6 after ratio test; skipping
# dino0325.png–dino0324.png: 26/37 inliers, t = [0.025, -0.295, -0.955]
# dino0324.png–dino0323.png: only 5 after ratio test; skipping
# dino0323.png–dino0327.png: only 4 after ratio test; skipping
# dino0327.png–dino0328.png: 46/72 inliers, t = [-0.051, 0.301, -0.952]
# dino0328.png–dino0329.png: 48/66 inliers, t = [0.011, -0.168, 0.986]
# dino0329.png–dino0331.png: only 6 after ratio test; skipping
# dino0331.png–dino0338.png: only 1 after ratio test; skipping
# dino0338.png–dino0337.png: 68/98 inliers, t = [-0.013, 0.598, -0.802]
# dino0337.png–dino0336.png: 55/79 inliers, t = [-0.008, 0.943, -0.332]
# dino0336.png–dino0335.png: only 6 after ratio test; skipping
# dino0335.png–dino0334.png: 56/81 inliers, t = [-0.014, -0.381, 0.925]
# dino0334.png–dino0333.png: 44/74 inliers, t = [-0.052, 0.417, -0.907]
# dino0333.png–dino0332.png: 62/86 inliers, t = [-0.018, 0.683, -0.730]
# dino0332.png–dino0339.png: only 1 after ratio test; skipping
# dino0339.png–dino0340.png: 78/117 inliers, t = [0.010, -0.109, 0.994]
# dino0340.png–dino0341.png: 70/105 inliers, t = [-0.019, 0.228, 0.974]
# dino0341.png–dino0342.png: 50/71 inliers, t = [0.036, 0.276, 0.961]
# dino0342.png–dino0348.png: only 2 after ratio test; skipping
# dino0348.png–dino0349.png: 48/66 inliers, t = [-0.037, -0.415, -0.909]
# dino0349.png–dino0350.png: 57/86 inliers, t = [-0.006, 0.362, -0.932]
# dino0350.png–dino0363.png: only 4 after ratio test; skipping
# dino0363.png–dino0362.png: 66/96 inliers, t = [0.057, 0.830, 0.555]
# dino0362.png–dino0361.png: 44/70 inliers, t = [-0.021, 0.264, 0.964]
# dino0361.png–dino0360.png: 34/47 inliers, t = [0.030, 0.126, 0.992]
# dino0360.png–dino0359.png: only 6 after ratio test; skipping
# dino0359.png–dino0358.png: 20/32 inliers, t = [-0.012, -0.366, -0.930]
# dino0358.png–dino0357.png: 42/59 inliers, t = [0.005, -0.900, -0.437]
# dino0357.png–dino0356.png: 63/87 inliers, t = [-0.023, -0.160, -0.987]
# dino0356.png–dino0355.png: 73/102 inliers, t = [-0.093, 0.849, -0.520]
# dino0355.png–dino0354.png: 72/116 inliers, t = [-0.015, 0.916, -0.401]
# dino0354.png–dino0353.png: 84/119 inliers, t = [-0.007, -0.500, -0.866]
# Done.  Inlier visuals in ‘matches/’, summary in ‘pair_results.csv’.

# %%
# ── cell: Initial 3D Reconstruction via E decomposition ──

import numpy as np
import cv2

# assume these are already in your notebook:
#   K           : (3×3) calibration matrix
#   F           : (3×3) fundamental matrix from findFundamentalMat()
#   pts1, pts2  : (N×2) all matched points before RANSAC
#   mask        : (N×1) inlier mask (0/1) from findFundamentalMat

# 1) Extract only the inlier correspondences
mask_bool = mask.ravel().astype(bool)
pts1_in = pts1[mask_bool]
pts2_in = pts2[mask_bool]

# 2) Compute and “fix” the Essential matrix
E = K.T @ F @ K
U, S, Vt = np.linalg.svd(E)
# enforce (σ,σ,0) singular values
sigma = (S[0] + S[1]) / 2.0
E = U @ np.diag([sigma, sigma, 0]) @ Vt

# 3) Build the four (R, t) hypotheses
W = np.array([[0, -1,  0],
              [1,  0,  0],
              [0,  0,  1]])
R1 = U @ W @ Vt
R2 = U @ W.T @ Vt
t0 = U[:, 2]

# ensure det(R)=+1
if np.linalg.det(R1) < 0: R1 *= -1
if np.linalg.det(R2) < 0: R2 *= -1

candidates = [
    (R1,  t0),
    (R1, -t0),
    (R2,  t0),
    (R2, -t0),
]

# helper: triangulate and count positive‐depth points
def count_in_front(R, t, K, pts1, pts2):
    # Projection matrices
    P1 = K @ np.hstack((np.eye(3), np.zeros((3,1))))
    P2 = K @ np.hstack((R, t.reshape(3,1)))
    # need points in normalized coordinates (undistorted)
    p1n = cv2.undistortPoints(pts1.reshape(-1,1,2), K, None)
    p2n = cv2.undistortPoints(pts2.reshape(-1,1,2), K, None)
    # triangulate (4×N)
    X4 = cv2.triangulatePoints(P1, P2, p1n, p2n)
    X3 = (X4[:3] / X4[3]).T  # N×3
    # depths in cam1 = Z, in cam2 = third coord of R·X + t
    z1 =  X3[:, 2]
    z2 = (R @ X3.T + t.reshape(3,1))[2]
    return np.sum((z1 > 0) & (z2 > 0)), X4

# 4) Pick the best pose
best_count = 0
for R_c, t_c in candidates:
    cnt, X4 = count_in_front(R_c, t_c, K, pts1_in, pts2_in)
    if cnt > best_count:
        best_count = cnt
        R_final, t_final, X4_final = R_c, t_c, X4

print(f"→ picked pose with {best_count} points in front.")
print("Rotation R_final:\n", R_final)
print("Translation t_final:\n", t_final)

# 5) (optional) convert to Euclidean 3D
X3D = (X4_final[:3] / X4_final[3]).T  # shape: (best_count×3)
print("First few 3D points:\n", X3D[:5])
# Out:
# → picked pose with 84 points in front.
# Rotation R_final:
#  [[ 0.99672795 -0.08008046  0.01097805]
#  [ 0.07973585  0.99639762  0.02887849]
#  [-0.01325111 -0.02790866  0.99952264]]
# Translation t_final:
#  [-0.00692055 -0.49965152 -0.86619886]
# First few 3D points:
#  [[-2.376378  -1.3716363 23.33098  ]
#  [-2.376358  -1.3714566 23.331608 ]
#  [-2.3762972 -1.3714077 23.331572 ]
#  [-2.3762898 -1.3713775 23.3317   ]
#  [-2.3761408 -1.3717183 23.330488 ]]

# %%
import os
import cv2
import numpy as np

# Initialize counters
skipped_count = 0
failed_count = 0
working_count = 0

# 0) Reconstruct inlier_matches from your initial pair
#    (good = list of DMatch, mask = Nx1 mask from findFundamentalMat)
mask_bool = mask.ravel().astype(bool)
inlier_matches = [m for m, valid in zip(good, mask_bool) if valid]

# 1) Convert homogeneous 4D points → Euclidean 3D
X3D = (X4_final[:3] / X4_final[3]).T  # shape: (M,3)

# 2) Build a map: kp1 index → index in X3D
kp1_to_3d = {m.queryIdx: i for i, m in enumerate(inlier_matches)}

# Prepare storage
R_all, t_all = [], []

# Set up SIFT with a higher number of features or switch to ORB for speed
sift = cv2.SIFT_create(nfeatures=1000)  # Increase features detected

# Use FLANN-based Matcher with cross-checking for better matches
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)  # Increase checks for better match quality
flann = cv2.FlannBasedMatcher(index_params, search_params)

# Iterate through the images
for img_name in sorted_imgs[2:]:
    # Load new image & compute features
    img = cv2.imread(os.path.join(IMG_DIR, img_name), cv2.IMREAD_GRAYSCALE)
    kp2, des2 = sift.detectAndCompute(img, None)

    # Match back to the first image's descriptors using FLANN
    raw2 = flann.knnMatch(des2, des1, k=2)

    # Apply ratio test to remove bad matches (adjusting threshold to improve results)
    good2 = [m for m, n in raw2 if m.distance < 0.75 * n.distance]  # Experiment with 0.75 or adjust

    # Collect 3D–2D correspondences
    obj_pts, img_pts = [], []
    for m in good2:
        if m.trainIdx in kp1_to_3d:
            obj_pts.append(X3D[kp1_to_3d[m.trainIdx]])
            img_pts.append(kp2[m.queryIdx].pt)

    obj_pts = np.array(obj_pts, dtype=np.float32)
    img_pts = np.array(img_pts, dtype=np.float32)

    if len(obj_pts) < 6:
        skipped_count += 1
        print(f"{img_name}: only {len(obj_pts)} 3D–2D pairs, skipping")
        continue

    # 3) Solve PnP with RANSAC
    ok, rvec, tvec, inliers = cv2.solvePnPRansac(
        obj_pts, img_pts, K, None,
        reprojectionError=6.0,  # Relaxed reprojection error (testing lower error)
        confidence=0.99,
        flags=cv2.SOLVEPNP_UPNP  # Switch to UPNP for better robustness
    )
    
    if not ok:
        failed_count += 1
        print(f"{img_name}: PnP failed")
        continue

    # 4) Convert rotation vector → matrix
    R, _ = cv2.Rodrigues(rvec)

    print(f"{img_name}:")
    print(" R =\n", R)
    print(" t =", tvec.ravel(), "\n")

    R_all.append(R)
    t_all.append(tvec)
    working_count += 1

# Print final stats
print(f"Stats:")
print(f"Skipped: {skipped_count}")
print(f"Failed: {failed_count}")
print(f"Working: {working_count}")
# Out:
# dino0047.png: only 2 3D–2D pairs, skipping
# dino0046.png: only 1 3D–2D pairs, skipping
# dino0045.png: only 1 3D–2D pairs, skipping
# dino0044.png: only 0 3D–2D pairs, skipping
# dino0043.png: only 0 3D–2D pairs, skipping
# dino0042.png: only 3 3D–2D pairs, skipping
# dino0041.png: only 4 3D–2D pairs, skipping
# dino0040.png: only 3 3D–2D pairs, skipping
# dino0039.png: only 2 3D–2D pairs, skipping
# dino0038.png: PnP failed
# dino0037.png: PnP failed
# dino0036.png:
#  R =
#  [[-0.99664295 -0.05521609  0.06044845]
#  [ 0.05331393 -0.99804416 -0.03264175]
#  [ 0.06213257 -0.02930942  0.99763746]]
#  t = [ -3.85385632  -0.48060446 -23.16041692]
#
# dino0035.png:
#  R =
#  [[-0.99735408  0.05655303  0.04567927]
#  [-0.06186083 -0.99026905 -0.12466131]
#  [ 0.03818479 -0.12715722  0.9911473 ]]
#  t = [ -3.35766887   1.40333756 -23.2000828 ]
#
# dino0034.png:
#  R =
#  [[-0.98948768  0.1379784   0.04331396]
#  [-0.14168763 -0.98491958 -0.09928767]
#  [ 0.02896121 -0.10438098  0.99411562]]
#  t = [ -3.17216546   0.62900293 -23.26098848]
#
# dino0033.png:
#  R =
#  [[-0.98673176  0.16206159  0.00982218]
#  [-0.16177257 -0.97623017 -0.1442369 ]
#  [-0.01378655 -0.14391209  0.98949444]]
#  t = [ -2.35114397   1.64193451 -23.30820835]
#
# dino0032.png:
#  R =
#  [[-0.96330485  0.26746797 -0.02246432]
#  [-0.25639344 -0.94171253 -0.21780707]
#  [-0.07941134 -0.2040549   0.97573328]]
#  t = [ -1.39764621   3.18094665 -23.22612035]
#
# dino0031.png:
#  R =
#  [[-0.94793642  0.31772081 -0.02168002]
#  [-0.30476437 -0.92481567 -0.22767226]
#  [-0.09238624 -0.20921153  0.97349644]]
#  t = [ -1.31051393   3.31936113 -23.21191871]
#
# dino0030.png:
#  R =
#  [[-0.92293099  0.38387397 -0.02896831]
#  [-0.36467014 -0.89590579 -0.25370947]
#  [-0.12334534 -0.22359246  0.9668466 ]]
#  t = [ -0.99032053   3.82416857 -23.15008214]
#
# dino0006.png: only 2 3D–2D pairs, skipping
# dino0005.png: only 2 3D–2D pairs, skipping
# dino0004.png: only 3 3D–2D pairs, skipping
# dino0003.png: only 1 3D–2D pairs, skipping
# dino0002.png: only 1 3D–2D pairs, skipping
# dino0001.png: only 1 3D–2D pairs, skipping
# dino0050.png: only 1 3D–2D pairs, skipping
# dino0051.png: only 0 3D–2D pairs, skipping
# dino0052.png: only 1 3D–2D pairs, skipping
# dino0053.png: only 2 3D–2D pairs, skipping
# dino0054.png: only 0 3D–2D pairs, skipping
# dino0055.png: only 0 3D–2D pairs, skipping
# dino0056.png: only 0 3D–2D pairs, skipping
# dino0057.png: only 2 3D–2D pairs, skipping
# dino0058.png: only 4 3D–2D pairs, skipping
# dino0059.png: only 1 3D–2D pairs, skipping
# dino0060.png: only 4 3D–2D pairs, skipping
# dino0061.png: PnP failed
# dino0062.png:
#  R =
#  [[-0.99602691 -0.08877143 -0.00707272]
#  [ 0.08823936 -0.99452176  0.05603816]
#  [-0.01200856  0.05519142  0.99840358]]
#  t = [ -2.3230963   -2.46181746 -23.24001295]
#
# dino0063.png:
#  R =
#  [[-0.9986294  -0.04767019  0.02160712]
#  [ 0.04678508 -0.99811303 -0.03976855]
#  [ 0.02346212 -0.03870315  0.99897527]]
#  t = [ -2.94202383  -0.32993975 -23.29677488]
#
# dino0064.png:
#  R =
#  [[-0.99987978  0.0151173   0.00344973]
#  [-0.01530956 -0.99776943 -0.06497517]
#  [ 0.00245979 -0.06502017  0.99788092]]
#  t = [ -2.43524643   0.11110431 -23.35724845]
#
# dino0065.png:
#  R =
#  [[-0.97821446  0.20351637 -0.04095789]
#  [-0.19366296 -0.96568284 -0.17306445]
#  [-0.07477378 -0.16136213  0.98405851]]
#  t = [ -1.08930181   2.25320636 -23.35103934]
#
# dino0066.png:
#  R =
#  [[-0.96548223  0.25772028 -0.03774013]
#  [-0.2454573  -0.94871578 -0.1992212 ]
#  [-0.087148   -0.18308094  0.97922755]]
#  t = [ -1.05978412   2.76368745 -23.29747339]
#
# dino0067.png:
#  R =
#  [[-0.95952018  0.28026137 -0.02783129]
#  [-0.27041023 -0.94437866 -0.18715571]
#  [-0.07873579 -0.17205382  0.98193592]]
#  t = [ -1.24588919   2.42885535 -23.32551139]
#
# dino0068.png:
#  R =
#  [[-0.96145268  0.27384301 -0.02487456]
#  [-0.26653549 -0.95037261 -0.16047038]
#  [-0.06758379 -0.14765473  0.98672717]]
#  t = [ -1.32826219   1.80724299 -23.37728545]
#
# dino0069.png:
#  R =
#  [[-0.92190707  0.38651278 -0.02636708]
#  [-0.37043245 -0.89938745 -0.23212499]
#  [-0.11343349 -0.20423045  0.97232853]]
#  t = [ -1.0449556    3.30210825 -23.22802977]
#
# dino0070.png:
#  R =
#  [[-0.91817445  0.39554669 -0.02232697]
#  [-0.38303786 -0.90070711 -0.20496022]
#  [-0.10118139 -0.17963716  0.97851562]]
#  t = [ -1.11795835   2.63657014 -23.30958139]
#
# dino0071.png:
#  R =
#  [[-0.91006959  0.41395153 -0.02043233]
#  [-0.40305642 -0.89544584 -0.18900337]
#  [-0.09653428 -0.16377084  0.98176384]]
#  t = [ -1.11766803   2.22393735 -23.35270498]
#
# dino0072.png:
#  R =
#  [[-0.80656442  0.58741368 -0.06632502]
#  [-0.56630733 -0.79997679 -0.19832585]
#  [-0.1695578  -0.12240222  0.97788949]]
#  t = [  0.43691459   2.18448241 -23.37913688]
#
# dino0073.png:
#  R =
#  [[-0.9224847   0.38589333 -0.01040771]
#  [-0.37804253 -0.90851762 -0.17798755]
#  [-0.0781398  -0.16025623  0.9839777 ]]
#  t = [ -1.41954112   2.00845397 -23.35582251]
#
# dino0074.png: PnP failed
# dino0075.png: PnP failed
# dino0090.png: only 3 3D–2D pairs, skipping
# dino0091.png: only 3 3D–2D pairs, skipping
# dino0092.png: only 5 3D–2D pairs, skipping
# dino0093.png: only 2 3D–2D pairs, skipping
# dino0094.png: only 3 3D–2D pairs, skipping
# dino0095.png: only 1 3D–2D pairs, skipping
# dino0096.png: only 2 3D–2D pairs, skipping
# dino0097.png: only 1 3D–2D pairs, skipping
# dino0145.png: only 1 3D–2D pairs, skipping
# dino0144.png: only 3 3D–2D pairs, skipping
# dino0143.png: only 1 3D–2D pairs, skipping
# dino0142.png: only 4 3D–2D pairs, skipping
# dino0141.png: only 3 3D–2D pairs, skipping
# dino0140.png: only 5 3D–2D pairs, skipping
# dino0139.png: only 2 3D–2D pairs, skipping
# dino0138.png: only 2 3D–2D pairs, skipping
# dino0137.png: only 2 3D–2D pairs, skipping
# dino0136.png: only 5 3D–2D pairs, skipping
# dino0135.png: only 4 3D–2D pairs, skipping
# dino0134.png:
#  R =
#  [[-0.99221093 -0.10820723 -0.06171434]
#  [ 0.10328244 -0.99158294  0.07807697]
#  [-0.06964338  0.07109482  0.99503534]]
#  t = [ -1.06584278  -2.9362378  -23.27644762]
#
# dino0133.png:
#  R =
#  [[-0.9927339  -0.11985676 -0.01066553]
#  [ 0.11964311 -0.99263866  0.01881557]
#  [-0.01284219  0.0174028   0.99976608]]
#  t = [ -2.27407499  -1.51615571 -23.32494455]
#
# dino0132.png:
#  R =
#  [[-0.99988819 -0.00868237 -0.01217473]
#  [ 0.00899996 -0.99961415 -0.02627819]
#  [-0.01194187 -0.02638483  0.99958053]]
#  t = [ -2.10343128  -0.73652055 -23.37952808]
#
# dino0131.png:
#  R =
#  [[-0.9948147   0.06011864 -0.08203335]
#  [-0.05264886 -0.99451594 -0.09036673]
#  [-0.0870162  -0.08557919  0.99252425]]
#  t = [ -0.36708391   0.6192665  -23.47417565]
#
# dino0130.png:
#  R =
#  [[-0.98814959  0.13007648 -0.08148921]
#  [-0.11968538 -0.98534576 -0.12152839]
#  [-0.09610303 -0.11033516  0.98923726]]
#  t = [ -0.26799294   1.19960459 -23.45293483]
#
# dino0129.png:
#  R =
#  [[-0.97781119  0.20270645 -0.05287122]
#  [-0.19109255 -0.96649245 -0.17139421]
#  [-0.08584235 -0.15748788  0.98378283]]
#  t = [ -0.81150678   2.21923138 -23.36566299]
#
# dino0128.png:
#  R =
#  [[-0.96369511  0.25482923 -0.07971072]
#  [-0.23728836 -0.9542577  -0.18189687]
#  [-0.12241721 -0.1563787   0.98008149]]
#  t = [ -0.08028366   2.37130004 -23.36516591]
#
# dino0127.png:
#  R =
#  [[-0.96176432  0.27218409 -0.03041723]
#  [-0.26438823 -0.95167722 -0.15623484]
#  [-0.07147202 -0.14221914  0.98725147]]
#  t = [ -1.2019628    1.71173685 -23.39140791]
#
# dino0126.png:
#  R =
#  [[-0.93682653  0.34605105 -0.05103643]
#  [-0.32848185 -0.92048313 -0.21168486]
#  [-0.12023194 -0.18154746  0.97600451]]
#  t = [ -0.5603357    2.89594758 -23.29909065]
#
# dino0125.png:
#  R =
#  [[-0.9209089   0.38773396 -0.03986439]
#  [-0.36970219 -0.90129668 -0.22579764]
#  [-0.12347906 -0.19320111  0.97335824]]
#  t = [ -0.7260021    3.15359905 -23.26100257]
#
# dino0124.png:
#  R =
#  [[-0.90773578  0.41871291 -0.02636765]
#  [-0.403107   -0.88787028 -0.22179069]
#  [-0.11627768 -0.19069836  0.97473773]]
#  t = [ -0.96710382   2.99916048 -23.27246133]
#
# dino0123.png:
#  R =
#  [[-0.90642591  0.42231332 -0.00659714]
#  [-0.41303904 -0.88956808 -0.19510864]
#  [-0.08826558 -0.17412665  0.98075945]]
#  t = [ -1.4203263   2.3507229 -23.3237473]
#
# dino0122.png: PnP failed
# dino0121.png: PnP failed
# dino0120.png: PnP failed
# dino0119.png: only 4 3D–2D pairs, skipping
# dino0118.png: only 4 3D–2D pairs, skipping
# dino0117.png: only 3 3D–2D pairs, skipping
# dino0116.png: only 4 3D–2D pairs, skipping
# dino0112.png: only 5 3D–2D pairs, skipping
# dino0111.png: only 5 3D–2D pairs, skipping
# dino0110.png: PnP failed
# dino0109.png: only 5 3D–2D pairs, skipping
# dino0106.png: only 5 3D–2D pairs, skipping
# dino0105.png: only 4 3D–2D pairs, skipping
# dino0104.png: only 4 3D–2D pairs, skipping
# dino0103.png: only 3 3D–2D pairs, skipping
# dino0102.png: only 1 3D–2D pairs, skipping
# dino0101.png: only 2 3D–2D pairs, skipping
# dino0100.png: only 1 3D–2D pairs, skipping
# dino0099.png: only 2 3D–2D pairs, skipping
# dino0098.png: only 3 3D–2D pairs, skipping
# dino0146.png: only 1 3D–2D pairs, skipping
# dino0147.png: only 2 3D–2D pairs, skipping
# dino0148.png: only 4 3D–2D pairs, skipping
# dino0149.png: only 3 3D–2D pairs, skipping
# dino0150.png: only 3 3D–2D pairs, skipping
# dino0151.png: only 1 3D–2D pairs, skipping
# dino0152.png: PnP failed
# dino0157.png:
#  R =
#  [[-0.91230652  0.40923821 -0.0148626 ]
#  [-0.39675066 -0.89229172 -0.21541682]
#  [-0.10141857 -0.19062942  0.97640908]]
#  t = [ -1.25938408   2.85949425 -23.27601739]
#
# dino0158.png:
#  R =
#  [[-0.8295813   0.55711888 -0.03759544]
#  [-0.53863929 -0.81617511 -0.2091074 ]
#  [-0.14718214 -0.15322121  0.97716973]]
#  t = [ -0.32962031   2.47954719 -23.35131534]
#
# dino0159.png:
#  R =
#  [[-0.88693326  0.46164708  0.01521074]
#  [-0.45450589 -0.86639862 -0.20682802]
#  [-0.08230299 -0.19035602  0.97825907]]
#  t = [ -1.82885892   2.55741318 -23.27322493]
#
# dino0160.png:
#  R =
#  [[-0.96808955  0.23460603  0.08810584]
#  [-0.2425662  -0.96554727 -0.09423432]
#  [ 0.06296242 -0.11259876  0.99164371]]
#  t = [ -4.03387905   0.29806565 -23.13459622]
#
# dino0161.png: PnP failed
# dino0162.png: only 1 3D–2D pairs, skipping
# dino0163.png: only 1 3D–2D pairs, skipping
# dino0164.png: only 5 3D–2D pairs, skipping
# dino0165.png: PnP failed
# dino0166.png: only 3 3D–2D pairs, skipping
# dino0167.png: PnP failed
# dino0168.png: only 2 3D–2D pairs, skipping
# dino0169.png: only 4 3D–2D pairs, skipping
# dino0170.png: only 1 3D–2D pairs, skipping
# dino0171.png: only 4 3D–2D pairs, skipping
# dino0172.png: only 2 3D–2D pairs, skipping
# dino0173.png: only 2 3D–2D pairs, skipping
# dino0174.png: only 1 3D–2D pairs, skipping
# dino0175.png: only 0 3D–2D pairs, skipping
# dino0176.png: only 1 3D–2D pairs, skipping
# dino0177.png: only 1 3D–2D pairs, skipping
# dino0196.png: only 0 3D–2D pairs, skipping
# dino0195.png: only 1 3D–2D pairs, skipping
# dino0194.png:
#  R =
#  [[-0.98714082  0.10238543 -0.12276081]
#  [-0.0885299  -0.9895907  -0.11345794]
#  [-0.13309939 -0.10113097  0.98592955]]
#  t = [  0.65932299   1.07950895 -23.45094931]
#
# dino0193.png:
#  R =
#  [[-0.97539394  0.1709874  -0.13917601]
#  [-0.15210425 -0.97887674 -0.13661857]
#  [-0.15959621 -0.11208767  0.98079835]]
#  t = [  1.16431308   1.48352452 -23.40968795]
#
# dino0192.png:
#  R =
#  [[-0.94330004  0.31141089 -0.11492736]
#  [-0.28333254 -0.93574773 -0.20999726]
#  [-0.17293845 -0.16552776  0.97092371]]
#  t = [  0.86741304   2.94290296 -23.28383028]
#
# dino0191.png:
#  R =
#  [[-0.93136432  0.35907981 -0.06018464]
#  [-0.33832787 -0.91463313 -0.22131538]
#  [-0.13451675 -0.18576311  0.97334337]]
#  t = [ -0.31605338   3.10526754 -23.27656995]
#
# dino0190.png:
#  R =
#  [[-0.91920446  0.39267697 -0.02946106]
#  [-0.38370246 -0.90998678 -0.15715113]
#  [-0.08851881 -0.13314974  0.98713503]]
#  t = [ -0.95788796   1.50684084 -23.41656987]
#
# dino0189.png:
#  R =
#  [[-0.8798496   0.47372655 -0.03805056]
#  [-0.45079142 -0.85724034 -0.24884956]
#  [-0.15050511 -0.20179732  0.96779443]]
#  t = [ -0.552825     3.55918915 -23.20710524]
#
# dino0188.png: PnP failed
# dino0187.png: only 3 3D–2D pairs, skipping
# dino0186.png: only 1 3D–2D pairs, skipping
# dino0185.png: only 3 3D–2D pairs, skipping
# dino0184.png: only 5 3D–2D pairs, skipping
# dino0183.png: only 3 3D–2D pairs, skipping
# dino0182.png: only 4 3D–2D pairs, skipping
# dino0181.png: only 4 3D–2D pairs, skipping
# dino0180.png: only 4 3D–2D pairs, skipping
# dino0179.png: only 3 3D–2D pairs, skipping
# dino0178.png: only 5 3D–2D pairs, skipping
# dino0197.png: only 0 3D–2D pairs, skipping
# dino0198.png: only 0 3D–2D pairs, skipping
# dino0199.png: only 1 3D–2D pairs, skipping
# dino0200.png: only 1 3D–2D pairs, skipping
# dino0201.png:
#  R =
#  [[-0.98635781 -0.07910713 -0.1443618 ]
#  [ 0.08497    -0.99577212 -0.0348995 ]
#  [-0.14099066 -0.04668982  0.98890935]]
#  t = [  0.91624986  -0.34960442 -23.46339317]
#
# dino0202.png:
#  R =
#  [[-0.98971848  0.02535399 -0.14076402]
#  [-0.01488668 -0.99707829 -0.07492173]
#  [-0.14225232 -0.07205591  0.98720425]]
#  t = [  0.96759406   0.34511645 -23.4620513 ]
#
# dino0203.png:
#  R =
#  [[-0.98070143  0.12813987 -0.14766473]
#  [-0.11003806 -0.98605287 -0.12486536]
#  [-0.16160546 -0.1062069   0.98112373]]
#  t = [  1.29098167   1.29940705 -23.41325599]
#
# dino0204.png:
#  R =
#  [[-0.97250993  0.19696907 -0.124208  ]
#  [-0.17671534 -0.97162988 -0.15718479]
#  [-0.15164475 -0.13091431  0.97972716]]
#  t = [  0.85758024   1.91482497 -23.39093516]
#
# dino0205.png:
#  R =
#  [[-0.94647783  0.29066738 -0.14032884]
#  [-0.26016208 -0.94434271 -0.20132697]
#  [-0.1910377  -0.15404327  0.96942007]]
#  t = [  1.42405728   2.7838768  -23.27596042]
#
# dino0206.png:
#  R =
#  [[-0.92668076  0.36073476 -0.10551393]
#  [-0.33321716 -0.91839501 -0.21334695]
#  [-0.17386513 -0.16254546  0.97126201]]
#  t = [  0.75492169   2.92633375 -23.28987188]
#
# dino0207.png:
#  R =
#  [[-0.9045991   0.42236124 -0.05754523]
#  [-0.40184215 -0.89000489 -0.2154395 ]
#  [-0.14220884 -0.17176228  0.97482017]]
#  t = [ -0.22726407   2.85104601 -23.31020919]
#
# dino0208.png:
#  R =
#  [[-0.88987242  0.45620413 -0.00220661]
#  [-0.44861155 -0.87592094 -0.17751108]
#  [-0.0829141  -0.1569723   0.98411633]]
#  t = [ -1.43693884   1.87437232 -23.36517036]
#
# dino0209.png: only 1 3D–2D pairs, skipping
# dino0210.png: only 4 3D–2D pairs, skipping
# dino0211.png: only 1 3D–2D pairs, skipping
# dino0212.png: only 2 3D–2D pairs, skipping
# dino0213.png: only 2 3D–2D pairs, skipping
# dino0214.png: only 2 3D–2D pairs, skipping
# dino0215.png: only 1 3D–2D pairs, skipping
# dino0216.png: PnP failed
# dino0217.png: only 5 3D–2D pairs, skipping
# dino0218.png: only 3 3D–2D pairs, skipping
# dino0242.png: only 1 3D–2D pairs, skipping
# dino0241.png: only 2 3D–2D pairs, skipping
# dino0240.png: only 2 3D–2D pairs, skipping
# dino0239.png: PnP failed
# dino0238.png:
#  R =
#  [[-0.96341137 -0.10415254 -0.24696312]
#  [ 0.11130025 -0.99367177 -0.01512162]
#  [-0.24382533 -0.04205539  0.96890689]]
#  t = [  3.33023747  -0.7456166  -23.23466324]
#
# dino0237.png:
#  R =
#  [[-0.97465286 -0.0441708  -0.2193188 ]
#  [ 0.05154967 -0.99827688 -0.02803383]
#  [-0.21770261 -0.03862906  0.97525041]]
#  t = [  2.7407785   -0.59263058 -23.31722877]
#
# dino0236.png:
#  R =
#  [[-0.98018152  0.0740181  -0.18375394]
#  [-0.06874543 -0.99702326 -0.03490953]
#  [-0.18579089 -0.02158543  0.98235219]]
#  t = [  2.05999346  -0.71623036 -23.38227521]
#
# dino0235.png:
#  R =
#  [[-0.97056466  0.17705556 -0.16326536]
#  [-0.1598597  -0.9806341  -0.11314431]
#  [-0.1801364  -0.08371431  0.98007285]]
#  t = [  1.74613128   0.91501908 -23.40151358]
#
# dino0234.png:
#  R =
#  [[-0.94762983  0.27007581 -0.17046046]
#  [-0.24885257 -0.95895549 -0.13592926]
#  [-0.2001752  -0.08639109  0.97594389]]
#  t = [  2.09607091   1.26492195 -23.35675505]
#
# dino0233.png:
#  R =
#  [[-0.93122332  0.34573015 -0.11529869]
#  [-0.32832871 -0.93315773 -0.14634516]
#  [-0.1581878  -0.09842416  0.98249138]]
#  t = [  0.95182228   1.35450245 -23.42613798]
#
# dino0232.png:
#  R =
#  [[-0.88967693  0.45452997 -0.04332988]
#  [-0.43656137 -0.87460945 -0.21088499]
#  [-0.13375027 -0.16870336  0.97655007]]
#  t = [ -0.4793271    2.68344093 -23.32528188]
#
# dino0231.png: only 4 3D–2D pairs, skipping
# dino0230.png: only 4 3D–2D pairs, skipping
# dino0229.png: only 4 3D–2D pairs, skipping
# dino0228.png: only 5 3D–2D pairs, skipping
# dino0227.png: only 1 3D–2D pairs, skipping
# dino0226.png: only 3 3D–2D pairs, skipping
# dino0225.png: only 2 3D–2D pairs, skipping
# dino0224.png: only 3 3D–2D pairs, skipping
# dino0223.png: only 3 3D–2D pairs, skipping
# dino0221.png: only 4 3D–2D pairs, skipping
# dino0220.png: only 3 3D–2D pairs, skipping
# dino0219.png: only 3 3D–2D pairs, skipping
# dino0243.png: only 1 3D–2D pairs, skipping
# dino0244.png: only 0 3D–2D pairs, skipping
# dino0245.png: only 1 3D–2D pairs, skipping
# dino0246.png: only 4 3D–2D pairs, skipping
# dino0247.png: PnP failed
# dino0248.png:
#  R =
#  [[-0.93702124 -0.15128179 -0.3148095 ]
#  [ 0.16521614 -0.98609506 -0.01789274]
#  [-0.30772525 -0.06877749  0.94898621]]
#  t = [  4.91112581  -0.54247436 -22.95772648]
#
# dino0249.png:
#  R =
#  [[-0.97425407  0.03048751 -0.22338201]
#  [-0.02537642 -0.99934714 -0.02571618]
#  [-0.2240202  -0.01938546  0.97439168]]
#  t = [  2.93892325  -0.83092175 -23.28491606]
#
# dino0250.png:
#  R =
#  [[-0.9622114   0.12170255 -0.24359333]
#  [-0.07657161 -0.97939835 -0.18685734]
#  [-0.26131592 -0.16114393  0.95170722]]
#  t = [  3.56415781   2.83436668 -23.03778016]
#
# dino0251.png:
#  R =
#  [[-0.9337514   0.29432249 -0.20367276]
#  [-0.24438924 -0.94002054 -0.2379817 ]
#  [-0.26149994 -0.17244032  0.94967474]]
#  t = [  2.93715462   3.68246047 -23.00641399]
#
# dino0252.png:
#  R =
#  [[-0.9353048   0.34391934 -0.08321306]
#  [-0.32731541 -0.93025977 -0.16577513]
#  [-0.13442304 -0.12781336  0.98264652]]
#  t = [  0.19104398   1.81421215 -23.41336917]
#
# dino0253.png: PnP failed
# dino0254.png: PnP failed
# dino0255.png: only 2 3D–2D pairs, skipping
# dino0256.png: only 2 3D–2D pairs, skipping
# dino0257.png: only 4 3D–2D pairs, skipping
# dino0258.png: only 2 3D–2D pairs, skipping
# dino0259.png: only 4 3D–2D pairs, skipping
# dino0260.png: only 2 3D–2D pairs, skipping
# dino0261.png: only 3 3D–2D pairs, skipping
# dino0262.png: only 4 3D–2D pairs, skipping
# dino0263.png: only 1 3D–2D pairs, skipping
# dino0264.png: only 1 3D–2D pairs, skipping
# dino0265.png: only 3 3D–2D pairs, skipping
# dino0286.png: only 3 3D–2D pairs, skipping
# dino0285.png: only 3 3D–2D pairs, skipping
# dino0284.png: PnP failed
# dino0283.png: PnP failed
# dino0282.png: PnP failed
# dino0281.png:
#  R =
#  [[-0.95977781 -0.144201   -0.24089962]
#  [ 0.14979619 -0.98870437 -0.00497674]
#  [-0.23746085 -0.0408624   0.97053728]]
#  t = [  3.14248486  -0.88396995 -23.25494246]
#
# dino0280.png:
#  R =
#  [[-0.90981251 -0.06769764 -0.40946091]
#  [-0.06001017 -0.95477872  0.29119818]
#  [-0.41065799  0.28950756  0.86460707]]
#  t = [  7.29875192  -8.2459715  -20.74338401]
#
# dino0279.png:
#  R =
#  [[-0.95660409  0.17123533 -0.23576913]
#  [-0.16961291 -0.9851325  -0.02730249]
#  [-0.23693899  0.01387181  0.97142549]]
#  t = [  3.46289636  -1.1170462  -23.20018081]
#
# dino0278.png:
#  R =
#  [[-0.8691741   0.47942135 -0.12120874]
#  [-0.43761762 -0.85985993 -0.2629291 ]
#  [-0.23027636 -0.17548808  0.95717121]]
#  t = [  1.42051939   3.91540417 -23.11106934]
#
# dino0277.png:
#  R =
#  [[-0.6657304   0.7427055  -0.07205259]
#  [-0.68177154 -0.64466199 -0.34583013]
#  [-0.30329951 -0.18110623  0.93552656]]
#  t = [  1.11811179   5.56464006 -22.78901312]
#
# dino0276.png: only 5 3D–2D pairs, skipping
# dino0275.png: PnP failed
# dino0274.png: only 2 3D–2D pairs, skipping
# dino0273.png: only 2 3D–2D pairs, skipping
# dino0272.png: only 3 3D–2D pairs, skipping
# dino0271.png: only 3 3D–2D pairs, skipping
# dino0270.png: only 1 3D–2D pairs, skipping
# dino0269.png: only 4 3D–2D pairs, skipping
# dino0268.png: only 4 3D–2D pairs, skipping
# dino0266.png: only 1 3D–2D pairs, skipping
# dino0287.png: only 5 3D–2D pairs, skipping
# dino0288.png: only 5 3D–2D pairs, skipping
# dino0289.png: PnP failed
# dino0290.png: only 4 3D–2D pairs, skipping
# dino0291.png: PnP failed
# dino0292.png:
#  R =
#  [[-0.93585084  0.17530729 -0.30569684]
#  [-0.17193335 -0.98436949 -0.03815276]
#  [-0.3076071   0.01685419  0.95136418]]
#  t = [  5.14924269  -0.86834112 -22.89521245]
#
# dino0293.png: only 5 3D–2D pairs, skipping
# dino0294.png: PnP failed
# dino0295.png: PnP failed
# dino0296.png: only 3 3D–2D pairs, skipping
# dino0297.png: PnP failed
# dino0298.png: only 4 3D–2D pairs, skipping
# dino0299.png: only 3 3D–2D pairs, skipping
# dino0300.png: only 3 3D–2D pairs, skipping
# dino0301.png: only 5 3D–2D pairs, skipping
# dino0310.png: only 5 3D–2D pairs, skipping
# dino0309.png: PnP failed
# dino0308.png: PnP failed
# dino0307.png: PnP failed
# dino0306.png: PnP failed
# dino0305.png: only 5 3D–2D pairs, skipping
# dino0304.png: only 3 3D–2D pairs, skipping
# dino0303.png: only 5 3D–2D pairs, skipping
# dino0302.png: only 4 3D–2D pairs, skipping
# dino0311.png: PnP failed
# dino0312.png: PnP failed
# dino0313.png: only 5 3D–2D pairs, skipping
# dino0314.png: PnP failed
# dino0315.png: PnP failed
# dino0316.png: only 5 3D–2D pairs, skipping
# dino0317.png: only 5 3D–2D pairs, skipping
# dino0320.png: only 3 3D–2D pairs, skipping
# dino0319.png: PnP failed
# dino0318.png:
#  R =
#  [[ 0.71079598 -0.69813738  0.08586781]
#  [ 0.59031784  0.65844533  0.46687751]
#  [-0.3824839  -0.28116535  0.88014324]]
#  t = [ -1.27217188  -8.58706254 -21.81942182]
#
# dino0321.png: PnP failed
# dino0322.png:
#  R =
#  [[-0.67546443 -0.68261763  0.27889241]
#  [-0.67231345  0.7254589   0.14732279]
#  [-0.30289012 -0.08799182 -0.9489547 ]]
#  t = [-9.04754214 -4.03923055 21.30689782]
#
# dino0326.png: only 3 3D–2D pairs, skipping
# dino0325.png: PnP failed
# dino0324.png: PnP failed
# dino0323.png: PnP failed
# dino0327.png: only 2 3D–2D pairs, skipping
# dino0328.png: only 5 3D–2D pairs, skipping
# dino0329.png: only 2 3D–2D pairs, skipping
# dino0331.png: only 5 3D–2D pairs, skipping
# dino0338.png: only 5 3D–2D pairs, skipping
# dino0337.png: only 5 3D–2D pairs, skipping
# dino0336.png: only 2 3D–2D pairs, skipping
# dino0335.png: only 2 3D–2D pairs, skipping
# dino0334.png: only 1 3D–2D pairs, skipping
# dino0333.png: only 1 3D–2D pairs, skipping
# dino0332.png: only 1 3D–2D pairs, skipping
# dino0339.png: only 3 3D–2D pairs, skipping
# dino0340.png: only 5 3D–2D pairs, skipping
# dino0341.png: only 2 3D–2D pairs, skipping
# dino0342.png: only 1 3D–2D pairs, skipping
# dino0348.png: PnP failed
# dino0349.png:
#  R =
#  [[ 0.98832202  0.06194603  0.13922025]
#  [-0.05514404  0.99711304 -0.05219879]
#  [-0.14205183  0.04391204  0.98888473]]
#  t = [ -0.81510813   2.45453218 -23.34162054]
#
# dino0350.png:
#  R =
#  [[ 0.97842497  0.12463892  0.16477169]
#  [-0.12110149  0.99214391 -0.03138301]
#  [-0.16738877  0.01075182  0.98583234]]
#  t = [ -1.34875429   1.80530527 -23.37688976]
#
# dino0363.png: PnP failed
# dino0362.png: only 3 3D–2D pairs, skipping
# dino0361.png: only 2 3D–2D pairs, skipping
# dino0360.png: only 5 3D–2D pairs, skipping
# dino0359.png: only 3 3D–2D pairs, skipping
# dino0358.png: only 4 3D–2D pairs, skipping
# dino0357.png:
#  R =
#  [[ 0.98820308  0.13818281  0.06603173]
#  [-0.1329948   0.98808957 -0.07740407]
#  [-0.07594117  0.06770907  0.99481075]]
#  t = [  0.99675731   2.84523644 -23.29075765]
#
# dino0356.png:
#  R =
#  [[ 0.99624362  0.0534195   0.06815424]
#  [-0.05215222  0.99843399 -0.02024121]
#  [-0.06912878  0.01661079  0.99746944]]
#  t = [  0.85009051   1.71782745 -23.4067666 ]
#
# dino0355.png:
#  R =
#  [[ 9.97029222e-01  4.13352106e-02  6.49933193e-02]
#  [-4.12344311e-02  9.99145314e-01 -2.89182367e-03]
#  [-6.50573046e-02  2.03270153e-04  9.97881509e-01]]
#  t = [  0.90914807   1.33994769 -23.42970746]
#
# dino0354.png:
#  R =
#  [[ 0.99494457 -0.02963074  0.09595484]
#  [ 0.02124145  0.99595559  0.08729982]
#  [-0.09815352 -0.08482026  0.99155   ]]
#  t = [  0.08445852  -0.62026306 -23.47645119]
#
# dino0353.png:
#  R =
#  [[ 0.99067983 -0.09187432  0.10056132]
#  [ 0.07954439  0.9895312   0.12041886]
#  [-0.11057196 -0.11129744  0.98761669]]
#  t = [ -0.11852071  -1.26326112 -23.45070809]
#
# Stats:
# Skipped: 186
# Failed: 43
# Working: 76

# %%
# ── cell: Visualize 3D points as a rotating GIF ──

import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from IPython.display import HTML

# 1) Point to your saved file:
npy_path = r"C:\Users\hassa\Downloads\dino\dino\output\points3d.npy"  # <— adjust this!

if not os.path.isfile(npy_path):
    raise FileNotFoundError(f"Could not find points file at {npy_path}")

# 2) Load the 3D points
pts = np.load(npy_path)

# 3) Create a 3D scatter
fig = plt.figure(figsize=(6,6))
ax  = fig.add_subplot(111, projection='3d')
sc  = ax.scatter(pts[:,0], pts[:,1], pts[:,2], s=2)

# keep the box aspect equal
max_range = (pts.max(axis=0) - pts.min(axis=0)).max() / 2.0
mid       = pts.mean(axis=0)
ax.set_xlim(mid[0]-max_range, mid[0]+max_range)
ax.set_ylim(mid[1]-max_range, mid[1]+max_range)
ax.set_zlim(mid[2]-max_range, mid[2]+max_range)
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')

# 4) Animation callback: rotate azimuth
def update(angle):
    ax.view_init(elev=30, azim=angle)
    return sc,

# 5) Build and save the animation
ani = animation.FuncAnimation(
    fig, update,
    frames=np.linspace(0, 360, 120),
    interval=100
)
gif_path = "3d_points.gif"
ani.save(gif_path, writer='pillow', fps=10)
plt.close(fig)

# 6) Display inline
HTML(f'<img src="{gif_path}" />')
# Out:
# <img src="3d_points.gif" />

# %%
# If you haven’t already:
# !pip install open3d

import open3d as o3d
import numpy as np

# 1) Load your optimized points (adjust the path as needed)
pts = np.load(r"C:\Users\hassa\Downloads\dino\dino\output\points3d.npy")

# 2) Build an Open3D point cloud
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(pts)
pcd.paint_uniform_color([0.75, 0.75, 0.75])  # light gray

# 3) Launch the interactive viewer
o3d.visualization.draw_geometries(
    [pcd],
    window_name="Dino 3D Point Cloud",
    width=1024,
    height=768
)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The handle is invalid.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: The requested transformation operation is not supported.

# %%
import os
import cv2
import csv
import numpy as np
import open3d as o3d

# --- PARAMETERS ---
IMG_DIR = '.'  # folder with your dino*.png
GOOD_FILE = 'dino_good_silhouette_images.txt'
ANG_FILE = 'dino_ang.txt'
PAR_FILE = 'dino_par.txt'

RATIO_THR = 0.7  # Lowe’s ratio test threshold
RANSAC_THR = 1.0  # RANSAC reprojection threshold (pixels)
MIN_MATCHES = 8  # minimum matches after ratio test

# --- 1. Load good‐silhouette list ---
with open(GOOD_FILE, 'r') as f:
    good_imgs = {ln.strip() for ln in f if ln.strip()}

# --- 2. Load angles and keep only good images ---
ang_map = {}
with open(ANG_FILE, 'r') as f:
    for ln in f:
        parts = ln.strip().split()
        if len(parts) != 3:
            continue
        try:
            lat, lon = float(parts[0]), float(parts[1])
        except ValueError:
            continue
        name = parts[2]
        if name in good_imgs:
            ang_map[name] = (lat, lon)

# sort by latitude, then longitude
sorted_imgs = sorted(ang_map.keys(), key=lambda n: (ang_map[n][0], ang_map[n][1]))

# --- 3. Parse calibration file to extract K ---
K = None
with open(PAR_FILE, 'r') as f:
    for ln in f:
        parts = ln.strip().split()
        if len(parts) >= 7 and parts[0].endswith('.png'):
            fx, cx = float(parts[1]), float(parts[3])
            fy, cy = float(parts[5]), float(parts[6])
            K = np.array([[fx,   0, cx],
                          [  0, fy, cy],
                          [  0,   0,  1]])
            break
if K is None:
    raise RuntimeError(f"Could not parse intrinsics from {PAR_FILE}")

# prepare SIFT or ORB and BFMatcher
sift = cv2.SIFT_create()  # ORB can be used instead: sift = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_L2)

# make output folders
os.makedirs('matches', exist_ok=True)

# CSV log
with open('pair_results.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['img1', 'img2', 'raw_matches', 'inliers', 't_x', 't_y', 't_z'])

    # --- 4. Loop over consecutive pairs ---
    for i in range(len(sorted_imgs) - 1):
        img1_name = sorted_imgs[i]
        img2_name = sorted_imgs[i+1]

        # load grayscale
        img1 = cv2.imread(os.path.join(IMG_DIR, img1_name), cv2.IMREAD_GRAYSCALE)
        img2 = cv2.imread(os.path.join(IMG_DIR, img2_name), cv2.IMREAD_GRAYSCALE)
        if img1 is None or img2 is None:
            print(f"Warning: couldn’t load {img1_name} or {img2_name}, skipping")
            continue

        # detect & describe
        kp1, des1 = sift.detectAndCompute(img1, None)
        kp2, des2 = sift.detectAndCompute(img2, None)

        # raw knn matches + Lowe’s ratio test
        raw = bf.knnMatch(des1, des2, k=2)
        good = []
        pts1, pts2 = [], []
        for m, n in raw:
            if m.distance < RATIO_THR * n.distance:
                good.append(m)
                pts1.append(kp1[m.queryIdx].pt)
                pts2.append(kp2[m.trainIdx].pt)

        pts1 = np.float32(pts1)
        pts2 = np.float32(pts2)
        raw_count = len(good)
        if raw_count < MIN_MATCHES:
            print(f"{img1_name}–{img2_name}: only {raw_count} after ratio test; skipping")
            continue

        # estimate Fundamental matrix via RANSAC
        F, mask = cv2.findFundamentalMat(pts1, pts2,
                                         cv2.FM_RANSAC,
                                         ransacReprojThreshold=RANSAC_THR,
                                         confidence=0.99)
        if F is None:
            print(f"{img1_name}–{img2_name}: Fundamental matrix failed; skipping")
            continue

        inlier_mask = mask.ravel().astype(bool)
        inlier_count = int(inlier_mask.sum())

        # --- 5. Compute Essential & recover pose ---
        E = K.T @ F @ K
        pts1_in = pts1[inlier_mask]
        pts2_in = pts2[inlier_mask]
        _, R, t, _ = cv2.recoverPose(E, pts1_in, pts2_in, K)

        # --- 6. Draw & save inlier matches ---
        mask_ints = [int(m) for m in inlier_mask]
        vis = cv2.drawMatches(
            img1, kp1, img2, kp2, good, None,
            matchColor=(0,255,0),
            singlePointColor=None,
            matchesMask=mask_ints,
            flags=cv2.DrawMatchesFlags_DEFAULT,
            matchesThickness=1
        )
        out_fn = f"matches/{img1_name[:-4]}_{img2_name[:-4]}_inliers.png"
        cv2.imwrite(out_fn, vis)

        # log to CSV
        tx, ty, tz = t.ravel()
        writer.writerow([img1_name, img2_name,
                         raw_count, inlier_count,
                         tx, ty, tz])

        print(f"{img1_name}–{img2_name}: {inlier_count}/{raw_count} inliers, t = [{tx:.3f}, {ty:.3f}, {tz:.3f}]")

    print("Done. Inlier visuals in ‘matches/’, summary in ‘pair_results.csv’.")
# Out:
# dino0049.png–dino0048.png: 61/83 inliers, t = [0.020, -0.471, -0.882]
# dino0048.png–dino0047.png: 54/82 inliers, t = [0.059, -0.864, 0.500]
# dino0047.png–dino0046.png: 45/77 inliers, t = [-0.005, -0.534, -0.846]
# dino0046.png–dino0045.png: 34/55 inliers, t = [0.035, -0.339, 0.940]
# dino0045.png–dino0044.png: 25/45 inliers, t = [0.048, 0.091, 0.995]
# dino0044.png–dino0043.png: 21/33 inliers, t = [-0.064, 0.381, 0.922]
# dino0043.png–dino0042.png: 13/22 inliers, t = [-0.002, -0.036, 0.999]
# dino0042.png–dino0041.png: 14/20 inliers, t = [-0.050, 0.039, 0.998]
# dino0041.png–dino0040.png: 14/23 inliers, t = [0.064, -0.224, -0.972]
# dino0040.png–dino0039.png: 21/34 inliers, t = [0.041, -0.464, -0.885]
# dino0039.png–dino0038.png: 26/47 inliers, t = [0.032, -0.220, -0.975]
# dino0038.png–dino0037.png: 45/74 inliers, t = [0.020, -0.414, -0.910]
# dino0037.png–dino0036.png: 53/81 inliers, t = [0.024, -0.326, -0.945]
# dino0036.png–dino0035.png: 71/104 inliers, t = [0.019, -0.433, -0.901]
# dino0035.png–dino0034.png: 69/103 inliers, t = [0.032, 0.319, -0.947]
# dino0034.png–dino0033.png: 103/125 inliers, t = [0.006, -0.457, 0.889]
# dino0033.png–dino0032.png: 99/138 inliers, t = [0.040, -0.225, -0.974]
# dino0032.png–dino0031.png: 110/137 inliers, t = [-0.032, -0.351, 0.936]
# dino0031.png–dino0030.png: 131/161 inliers, t = [0.013, -0.911, -0.413]
# dino0030.png–dino0006.png: only 5 after ratio test; skipping
# dino0006.png–dino0005.png: 70/103 inliers, t = [0.111, -0.891, -0.439]
# dino0005.png–dino0004.png: 73/92 inliers, t = [0.021, -0.991, -0.134]
# dino0004.png–dino0003.png: 76/97 inliers, t = [-0.039, -0.968, -0.249]
# dino0003.png–dino0002.png: 68/86 inliers, t = [-0.018, -0.575, -0.818]
# dino0002.png–dino0001.png: 89/103 inliers, t = [-0.001, 0.495, 0.869]
# dino0001.png–dino0050.png: 50/75 inliers, t = [-0.302, 0.263, 0.916]
# dino0050.png–dino0051.png: 49/73 inliers, t = [0.025, -0.319, 0.947]
# dino0051.png–dino0052.png: 40/68 inliers, t = [0.025, 0.426, 0.904]
# dino0052.png–dino0053.png: 38/70 inliers, t = [0.065, 0.462, 0.884]
# dino0053.png–dino0054.png: 28/49 inliers, t = [-0.064, -0.270, 0.961]
# dino0054.png–dino0055.png: 22/39 inliers, t = [0.004, -0.110, 0.994]
# dino0055.png–dino0056.png: 22/34 inliers, t = [0.012, -0.069, 0.998]
# dino0056.png–dino0057.png: 16/23 inliers, t = [-0.009, -0.042, 0.999]
# dino0057.png–dino0058.png: 13/18 inliers, t = [-0.023, -0.046, 0.999]
# dino0058.png–dino0059.png: 15/23 inliers, t = [0.039, -0.018, -0.999]
# dino0059.png–dino0060.png: 22/41 inliers, t = [0.014, 0.390, -0.921]
# dino0060.png–dino0061.png: 30/52 inliers, t = [0.016, -0.711, -0.703]
# dino0061.png–dino0062.png: 55/84 inliers, t = [0.020, 0.493, -0.870]
# dino0062.png–dino0063.png: 72/105 inliers, t = [0.061, -0.750, -0.659]
# dino0063.png–dino0064.png: 72/97 inliers, t = [0.035, 0.994, -0.107]
# dino0064.png–dino0065.png: 48/76 inliers, t = [0.050, -0.443, -0.895]
# dino0065.png–dino0066.png: 100/139 inliers, t = [0.017, 0.297, -0.955]
# dino0066.png–dino0067.png: 102/139 inliers, t = [0.034, 0.186, -0.982]
# dino0067.png–dino0068.png: 121/149 inliers, t = [0.104, -0.917, 0.385]
# dino0068.png–dino0069.png: 129/147 inliers, t = [-0.039, -0.597, 0.801]
# dino0069.png–dino0070.png: 134/155 inliers, t = [-0.013, -0.369, -0.929]
# dino0070.png–dino0071.png: 108/144 inliers, t = [-0.038, -0.885, -0.464]
# dino0071.png–dino0072.png: 111/139 inliers, t = [-0.090, -0.992, -0.092]
# dino0072.png–dino0073.png: 115/143 inliers, t = [-0.013, -0.286, -0.958]
# dino0073.png–dino0074.png: 109/149 inliers, t = [0.018, 0.229, 0.973]
# dino0074.png–dino0075.png: 106/133 inliers, t = [0.157, -0.956, 0.250]
# dino0075.png–dino0090.png: only 3 after ratio test; skipping
# dino0090.png–dino0091.png: 79/113 inliers, t = [0.051, -0.068, -0.996]
# dino0091.png–dino0092.png: 73/99 inliers, t = [0.009, -0.559, -0.829]
# dino0092.png–dino0093.png: 70/93 inliers, t = [0.027, -0.278, -0.960]
# dino0093.png–dino0094.png: 63/88 inliers, t = [-0.006, -0.493, 0.870]
# dino0094.png–dino0095.png: 62/87 inliers, t = [-0.077, -0.776, 0.626]
# dino0095.png–dino0096.png: 60/87 inliers, t = [-0.019, -0.206, -0.978]
# dino0096.png–dino0097.png: 68/93 inliers, t = [0.006, 0.635, -0.773]
# dino0097.png–dino0145.png: 44/67 inliers, t = [-0.808, 0.560, 0.181]
# dino0145.png–dino0144.png: 51/71 inliers, t = [-0.035, -0.302, -0.953]
# dino0144.png–dino0143.png: 38/63 inliers, t = [-0.009, -0.303, 0.953]
# dino0143.png–dino0142.png: 31/51 inliers, t = [-0.200, -0.698, 0.687]
# dino0142.png–dino0141.png: 25/38 inliers, t = [-0.023, -0.209, 0.978]
# dino0141.png–dino0140.png: 20/40 inliers, t = [-0.004, -0.130, 0.992]
# dino0140.png–dino0139.png: 16/26 inliers, t = [-0.454, 0.383, -0.804]
# dino0139.png–dino0138.png: 13/17 inliers, t = [-0.022, -0.007, 1.000]
# dino0138.png–dino0137.png: 15/23 inliers, t = [0.001, 0.278, -0.961]
# dino0137.png–dino0136.png: 21/31 inliers, t = [-0.001, -0.992, -0.124]
# dino0136.png–dino0135.png: 24/42 inliers, t = [-0.004, -0.161, -0.987]
# dino0135.png–dino0134.png: 47/70 inliers, t = [-0.005, -0.380, -0.925]
# dino0134.png–dino0133.png: 62/99 inliers, t = [-0.020, -0.502, -0.865]
# dino0133.png–dino0132.png: 69/107 inliers, t = [0.017, 0.274, -0.961]
# dino0132.png–dino0131.png: 71/107 inliers, t = [-0.019, -0.307, -0.952]
# dino0131.png–dino0130.png: 91/132 inliers, t = [0.046, -0.832, -0.554]
# dino0130.png–dino0129.png: 107/133 inliers, t = [0.075, -0.930, -0.360]
# dino0129.png–dino0128.png: 103/140 inliers, t = [0.039, -0.188, -0.981]
# dino0128.png–dino0127.png: 104/144 inliers, t = [0.023, 0.047, -0.999]
# dino0127.png–dino0126.png: 138/161 inliers, t = [0.044, -0.830, 0.556]
# dino0126.png–dino0125.png: 109/146 inliers, t = [0.006, -0.284, 0.959]
# dino0125.png–dino0124.png: 108/144 inliers, t = [0.013, -0.170, -0.985]
# dino0124.png–dino0123.png: 127/150 inliers, t = [-0.097, -0.992, -0.086]
# dino0123.png–dino0122.png: 109/136 inliers, t = [0.002, -0.331, -0.944]
# dino0122.png–dino0121.png: 105/132 inliers, t = [-0.027, 0.617, 0.787]
# dino0121.png–dino0120.png: 101/126 inliers, t = [-0.054, 0.399, 0.915]
# dino0120.png–dino0119.png: 79/112 inliers, t = [-0.024, -0.478, 0.878]
# dino0119.png–dino0118.png: 70/97 inliers, t = [-0.012, -1.000, 0.026]
# dino0118.png–dino0117.png: 43/66 inliers, t = [0.007, 0.873, 0.487]
# dino0117.png–dino0116.png: 25/43 inliers, t = [0.071, 0.896, 0.439]
# dino0116.png–dino0112.png: only 4 after ratio test; skipping
# dino0112.png–dino0111.png: 32/54 inliers, t = [0.203, 0.978, 0.037]
# dino0111.png–dino0110.png: 47/68 inliers, t = [0.067, 0.379, -0.923]
# dino0110.png–dino0109.png: 62/82 inliers, t = [-0.022, -0.620, -0.784]
# dino0109.png–dino0106.png: 30/46 inliers, t = [0.143, -0.883, 0.447]
# dino0106.png–dino0105.png: 74/102 inliers, t = [0.051, -0.686, 0.726]
# dino0105.png–dino0104.png: 76/109 inliers, t = [0.038, -0.128, -0.991]
# dino0104.png–dino0103.png: 66/98 inliers, t = [0.007, 0.639, 0.769]
# dino0103.png–dino0102.png: 74/100 inliers, t = [-0.091, -0.768, -0.634]
# dino0102.png–dino0101.png: 59/79 inliers, t = [0.000, 0.472, -0.882]
# dino0101.png–dino0100.png: 60/91 inliers, t = [0.029, 0.391, 0.920]
# dino0100.png–dino0099.png: 55/87 inliers, t = [0.044, -0.499, 0.866]
# dino0099.png–dino0098.png: 63/93 inliers, t = [-0.002, 0.056, 0.998]
# dino0098.png–dino0146.png: 43/62 inliers, t = [0.791, -0.534, -0.300]
# dino0146.png–dino0147.png: 47/66 inliers, t = [-0.008, 0.296, 0.955]
# dino0147.png–dino0148.png: 33/56 inliers, t = [0.011, -0.159, 0.987]
# dino0148.png–dino0149.png: 32/48 inliers, t = [-0.034, -0.372, 0.928]
# dino0149.png–dino0150.png: 12/21 inliers, t = [0.087, -0.014, 0.996]
# dino0150.png–dino0151.png: 14/20 inliers, t = [0.217, -0.012, 0.976]
# dino0151.png–dino0152.png: 12/16 inliers, t = [0.001, 0.099, 0.995]
# dino0152.png–dino0157.png: only 5 after ratio test; skipping
# dino0157.png–dino0158.png: 116/136 inliers, t = [0.031, -0.891, -0.454]
# dino0158.png–dino0159.png: 109/135 inliers, t = [-0.123, -0.987, -0.107]
# dino0159.png–dino0160.png: 94/124 inliers, t = [0.046, 0.438, 0.898]
# dino0160.png–dino0161.png: 95/121 inliers, t = [0.050, -0.424, -0.904]
# dino0161.png–dino0162.png: only 2 after ratio test; skipping
# dino0162.png–dino0163.png: 15/22 inliers, t = [-0.035, -0.994, -0.107]
# dino0163.png–dino0164.png: 23/30 inliers, t = [0.140, -0.787, 0.601]
# dino0164.png–dino0165.png: 32/48 inliers, t = [0.018, -0.312, 0.950]
# dino0165.png–dino0166.png: 43/66 inliers, t = [0.034, -0.211, -0.977]
# dino0166.png–dino0167.png: 58/83 inliers, t = [0.086, -0.335, -0.938]
# dino0167.png–dino0168.png: 62/93 inliers, t = [0.257, -0.828, -0.498]
# dino0168.png–dino0169.png: 62/87 inliers, t = [0.083, -0.367, 0.926]
# dino0169.png–dino0170.png: 70/90 inliers, t = [-0.012, -0.252, -0.968]
# dino0170.png–dino0171.png: 61/98 inliers, t = [0.136, -0.663, -0.736]
# dino0171.png–dino0172.png: 67/96 inliers, t = [-0.128, -0.986, 0.104]
# dino0172.png–dino0173.png: 56/85 inliers, t = [-0.012, 0.264, 0.965]
# dino0173.png–dino0174.png: 59/77 inliers, t = [0.035, -0.511, -0.859]
# dino0174.png–dino0175.png: 54/78 inliers, t = [0.056, -0.956, 0.287]
# dino0175.png–dino0176.png: 57/86 inliers, t = [-0.022, 0.460, 0.888]
# dino0176.png–dino0177.png: 67/85 inliers, t = [-0.044, -0.460, -0.887]
# dino0177.png–dino0196.png: 13/22 inliers, t = [0.551, -0.110, -0.827]
# dino0196.png–dino0195.png: 8/12 inliers, t = [0.175, -0.150, -0.973]
# dino0195.png–dino0194.png: only 1 after ratio test; skipping
# dino0194.png–dino0193.png: 91/135 inliers, t = [0.031, -0.092, -0.995]
# dino0193.png–dino0192.png: 65/95 inliers, t = [-0.004, -0.254, -0.967]
# dino0192.png–dino0191.png: 106/141 inliers, t = [0.126, -0.750, 0.649]
# dino0191.png–dino0190.png: 117/140 inliers, t = [0.048, -0.334, -0.941]
# dino0190.png–dino0189.png: 119/142 inliers, t = [0.100, -0.937, -0.335]
# dino0189.png–dino0188.png: 109/135 inliers, t = [0.001, -0.253, 0.968]
# dino0188.png–dino0187.png: only 3 after ratio test; skipping
# dino0187.png–dino0186.png: 16/22 inliers, t = [0.025, -0.102, -0.994]
# dino0186.png–dino0185.png: 15/25 inliers, t = [0.112, -0.380, 0.918]
# dino0185.png–dino0184.png: 23/39 inliers, t = [0.045, -0.286, -0.957]
# dino0184.png–dino0183.png: 35/50 inliers, t = [0.031, -0.380, -0.924]
# dino0183.png–dino0182.png: 52/79 inliers, t = [0.043, -0.284, -0.958]
# dino0182.png–dino0181.png: 56/77 inliers, t = [0.061, -0.147, -0.987]
# dino0181.png–dino0180.png: 54/80 inliers, t = [0.103, -0.170, -0.980]
# dino0180.png–dino0179.png: 56/93 inliers, t = [0.042, 0.168, 0.985]
# dino0179.png–dino0178.png: 62/90 inliers, t = [0.043, 0.389, -0.920]
# dino0178.png–dino0197.png: 7/9 inliers, t = [-0.045, 0.133, 0.990]
# dino0197.png–dino0198.png: 27/38 inliers, t = [0.075, -0.516, 0.853]
# dino0198.png–dino0199.png: 19/34 inliers, t = [-0.012, -0.635, 0.772]
# dino0199.png–dino0200.png: 13/21 inliers, t = [-0.035, -0.038, 0.999]
# dino0200.png–dino0201.png: only 0 after ratio test; skipping
# dino0201.png–dino0202.png: 70/108 inliers, t = [0.017, -0.264, -0.964]
# dino0202.png–dino0203.png: 87/115 inliers, t = [0.050, -0.992, 0.112]
# dino0203.png–dino0204.png: 93/129 inliers, t = [-0.047, -0.408, -0.912]
# dino0204.png–dino0205.png: 113/132 inliers, t = [0.008, -0.480, 0.877]
# dino0205.png–dino0206.png: 115/143 inliers, t = [-0.090, -0.496, 0.864]
# dino0206.png–dino0207.png: 121/141 inliers, t = [0.031, -0.494, -0.869]
# dino0207.png–dino0208.png: 112/134 inliers, t = [0.066, -0.561, 0.825]
# dino0208.png–dino0209.png: only 5 after ratio test; skipping
# dino0209.png–dino0210.png: 29/38 inliers, t = [-0.032, -0.209, 0.977]
# dino0210.png–dino0211.png: 18/33 inliers, t = [0.087, -0.437, 0.895]
# dino0211.png–dino0212.png: 14/25 inliers, t = [0.034, -0.048, 0.998]
# dino0212.png–dino0213.png: 21/35 inliers, t = [-0.033, -0.677, 0.735]
# dino0213.png–dino0214.png: 20/32 inliers, t = [0.018, -0.772, 0.635]
# dino0214.png–dino0215.png: 28/44 inliers, t = [0.039, -0.942, 0.334]
# dino0215.png–dino0216.png: 43/64 inliers, t = [0.276, -0.775, -0.568]
# dino0216.png–dino0217.png: 40/68 inliers, t = [-0.007, -0.775, -0.632]
# dino0217.png–dino0218.png: 41/73 inliers, t = [-0.012, 0.282, 0.959]
# dino0218.png–dino0242.png: 7/8 inliers, t = [0.177, -0.430, 0.885]
# dino0242.png–dino0241.png: 25/40 inliers, t = [0.028, -0.498, 0.867]
# dino0241.png–dino0240.png: 7/11 inliers, t = [0.311, 0.558, -0.770]
# dino0240.png–dino0239.png: only 2 after ratio test; skipping
# dino0239.png–dino0238.png: 53/82 inliers, t = [0.075, -0.972, -0.225]
# dino0238.png–dino0237.png: 65/98 inliers, t = [-0.011, 0.226, -0.974]
# dino0237.png–dino0236.png: 89/117 inliers, t = [0.046, -0.386, -0.921]
# dino0236.png–dino0235.png: 82/122 inliers, t = [0.058, -0.525, -0.849]
# dino0235.png–dino0234.png: 91/132 inliers, t = [0.141, -0.925, 0.353]
# dino0234.png–dino0233.png: 112/141 inliers, t = [0.103, -0.805, 0.584]
# dino0233.png–dino0232.png: 100/132 inliers, t = [0.009, -0.161, 0.987]
# dino0232.png–dino0231.png: 24/35 inliers, t = [0.180, -0.768, -0.615]
# dino0231.png–dino0230.png: 60/86 inliers, t = [-0.049, -0.586, -0.809]
# dino0230.png–dino0229.png: 45/75 inliers, t = [-0.053, -0.376, 0.925]
# dino0229.png–dino0228.png: 28/50 inliers, t = [-0.036, 0.252, 0.967]
# dino0228.png–dino0227.png: 16/28 inliers, t = [-0.012, 0.097, 0.995]
# dino0227.png–dino0226.png: 19/30 inliers, t = [-0.059, -0.376, 0.925]
# dino0226.png–dino0225.png: 19/35 inliers, t = [-0.017, 0.927, 0.375]
# dino0225.png–dino0224.png: 32/46 inliers, t = [0.049, -0.593, -0.804]
# dino0224.png–dino0223.png: 30/47 inliers, t = [-0.018, -0.330, -0.944]
# dino0223.png–dino0221.png: only 3 after ratio test; skipping
# dino0221.png–dino0220.png: 36/54 inliers, t = [0.007, -0.436, 0.900]
# dino0220.png–dino0219.png: 55/74 inliers, t = [0.029, -0.412, -0.911]
# dino0219.png–dino0243.png: 25/40 inliers, t = [-0.450, 0.195, 0.871]
# dino0243.png–dino0244.png: 26/35 inliers, t = [-0.021, 0.230, 0.973]
# dino0244.png–dino0245.png: 21/30 inliers, t = [-0.044, -0.185, 0.982]
# dino0245.png–dino0246.png: only 3 after ratio test; skipping
# dino0246.png–dino0247.png: 31/57 inliers, t = [0.009, 0.213, -0.977]
# dino0247.png–dino0248.png: 40/61 inliers, t = [-0.039, 0.268, -0.963]
# dino0248.png–dino0249.png: 75/101 inliers, t = [0.034, -0.288, -0.957]
# dino0249.png–dino0250.png: 94/128 inliers, t = [0.071, -0.529, -0.846]
# dino0250.png–dino0251.png: 82/123 inliers, t = [0.038, -0.151, -0.988]
# dino0251.png–dino0252.png: 112/141 inliers, t = [0.047, -0.295, -0.954]
# dino0252.png–dino0253.png: 44/61 inliers, t = [0.128, -0.743, 0.657]
# dino0253.png–dino0254.png: 85/115 inliers, t = [-0.044, 0.207, 0.977]
# dino0254.png–dino0255.png: 68/101 inliers, t = [-0.040, -0.611, 0.791]
# dino0255.png–dino0256.png: 44/66 inliers, t = [-0.025, -0.336, -0.942]
# dino0256.png–dino0257.png: 31/51 inliers, t = [-0.009, -0.322, 0.947]
# dino0257.png–dino0258.png: 25/39 inliers, t = [-0.034, 0.194, 0.980]
# dino0258.png–dino0259.png: 20/33 inliers, t = [-0.029, 0.098, 0.995]
# dino0259.png–dino0260.png: 25/36 inliers, t = [0.072, -0.937, -0.341]
# dino0260.png–dino0261.png: 31/46 inliers, t = [0.080, -0.957, -0.279]
# dino0261.png–dino0262.png: 8/13 inliers, t = [0.036, 0.133, -0.991]
# dino0262.png–dino0263.png: 41/58 inliers, t = [0.120, -0.639, 0.760]
# dino0263.png–dino0264.png: 23/39 inliers, t = [0.009, -0.062, -0.998]
# dino0264.png–dino0265.png: 48/69 inliers, t = [0.023, -0.060, -0.998]
# dino0265.png–dino0286.png: 21/32 inliers, t = [0.716, -0.374, 0.589]
# dino0286.png–dino0285.png: 21/34 inliers, t = [-0.041, 0.216, 0.976]
# dino0285.png–dino0284.png: 15/23 inliers, t = [-0.005, 0.134, 0.991]
# dino0284.png–dino0283.png: 11/19 inliers, t = [0.833, 0.222, 0.507]
# dino0283.png–dino0282.png: 37/57 inliers, t = [-0.074, 0.582, -0.810]
# dino0282.png–dino0281.png: 48/74 inliers, t = [-0.055, 0.308, -0.950]
# dino0281.png–dino0280.png: 77/117 inliers, t = [0.034, -0.147, -0.989]
# dino0280.png–dino0279.png: 80/113 inliers, t = [-0.048, -0.426, -0.903]
# dino0279.png–dino0278.png: 95/131 inliers, t = [0.045, -0.213, 0.976]
# dino0278.png–dino0277.png: 60/84 inliers, t = [0.174, -0.613, 0.771]
# dino0277.png–dino0276.png: 88/107 inliers, t = [0.182, -0.948, -0.262]
# dino0276.png–dino0275.png: 74/100 inliers, t = [0.152, -0.988, 0.030]
# dino0275.png–dino0274.png: 49/71 inliers, t = [-0.004, -0.218, 0.976]
# dino0274.png–dino0273.png: 39/53 inliers, t = [-0.219, 0.758, 0.614]
# dino0273.png–dino0272.png: 25/40 inliers, t = [-0.075, 0.697, -0.713]
# dino0272.png–dino0271.png: 20/34 inliers, t = [0.141, -0.982, 0.125]
# dino0271.png–dino0270.png: 21/35 inliers, t = [0.060, -0.690, 0.721]
# dino0270.png–dino0269.png: 8/11 inliers, t = [-0.010, 0.087, -0.996]
# dino0269.png–dino0268.png: 20/31 inliers, t = [-0.036, 0.208, -0.978]
# dino0268.png–dino0266.png: 21/30 inliers, t = [0.106, -0.429, 0.897]
# dino0266.png–dino0287.png: 25/30 inliers, t = [-0.583, 0.186, 0.791]
# dino0287.png–dino0288.png: 33/46 inliers, t = [0.124, -0.720, 0.683]
# dino0288.png–dino0289.png: 14/17 inliers, t = [-0.054, 0.083, -0.995]
# dino0289.png–dino0290.png: 35/56 inliers, t = [0.151, -0.798, -0.583]
# dino0290.png–dino0291.png: 61/82 inliers, t = [-0.194, 0.976, -0.096]
# dino0291.png–dino0292.png: 93/109 inliers, t = [-0.052, 0.317, -0.947]
# dino0292.png–dino0293.png: 51/71 inliers, t = [0.064, -0.340, 0.938]
# dino0293.png–dino0294.png: 82/106 inliers, t = [0.014, -0.262, 0.965]
# dino0294.png–dino0295.png: 54/75 inliers, t = [-0.013, 0.122, 0.992]
# dino0295.png–dino0296.png: 44/55 inliers, t = [-0.147, 0.470, 0.870]
# dino0296.png–dino0297.png: 25/38 inliers, t = [0.054, -0.382, 0.922]
# dino0297.png–dino0298.png: 14/22 inliers, t = [-0.025, 0.016, 1.000]
# dino0298.png–dino0299.png: 29/38 inliers, t = [-0.082, 0.406, 0.910]
# dino0299.png–dino0300.png: 21/33 inliers, t = [-0.229, 0.652, -0.722]
# dino0300.png–dino0301.png: 67/86 inliers, t = [0.019, -0.280, 0.960]
# dino0301.png–dino0310.png: 24/38 inliers, t = [-0.947, 0.213, 0.240]
# dino0310.png–dino0309.png: 15/19 inliers, t = [0.604, -0.678, 0.418]
# dino0309.png–dino0308.png: 36/53 inliers, t = [-0.158, 0.299, -0.941]
# dino0308.png–dino0307.png: 25/35 inliers, t = [0.195, -0.296, -0.935]
# dino0307.png–dino0306.png: 41/63 inliers, t = [-0.100, 0.198, 0.975]
# dino0306.png–dino0305.png: 30/47 inliers, t = [0.055, -0.179, 0.982]
# dino0305.png–dino0304.png: 23/32 inliers, t = [-0.073, 0.234, 0.970]
# dino0304.png–dino0303.png: 23/31 inliers, t = [0.039, -0.154, -0.987]
# dino0303.png–dino0302.png: 98/103 inliers, t = [-0.032, 0.190, -0.981]
# dino0302.png–dino0311.png: 28/40 inliers, t = [-0.137, 0.031, -0.990]
# dino0311.png–dino0312.png: 36/47 inliers, t = [-0.449, 0.368, -0.814]
# dino0312.png–dino0313.png: 43/62 inliers, t = [-0.118, 0.062, 0.991]
# dino0313.png–dino0314.png: 36/54 inliers, t = [0.353, -0.236, 0.905]
# dino0314.png–dino0315.png: 108/116 inliers, t = [0.071, -0.050, 0.996]
# dino0315.png–dino0316.png: 16/24 inliers, t = [0.571, 0.010, -0.821]
# dino0316.png–dino0317.png: 14/22 inliers, t = [0.051, 0.013, -0.999]
# dino0317.png–dino0320.png: 12/15 inliers, t = [-0.078, -0.042, -0.996]
# dino0320.png–dino0319.png: only 7 after ratio test; skipping
# dino0319.png–dino0318.png: 7/8 inliers, t = [0.007, 0.076, 0.997]
# dino0318.png–dino0321.png: 7/8 inliers, t = [-0.055, 0.044, 0.998]
# dino0321.png–dino0322.png: 7/10 inliers, t = [0.566, 0.514, -0.644]
# dino0322.png–dino0326.png: only 1 after ratio test; skipping
# dino0326.png–dino0325.png: only 6 after ratio test; skipping
# dino0325.png–dino0324.png: 26/37 inliers, t = [0.025, -0.295, -0.955]
# dino0324.png–dino0323.png: only 5 after ratio test; skipping
# dino0323.png–dino0327.png: only 4 after ratio test; skipping
# dino0327.png–dino0328.png: 46/72 inliers, t = [-0.051, 0.301, -0.952]
# dino0328.png–dino0329.png: 48/66 inliers, t = [0.011, -0.168, 0.986]
# dino0329.png–dino0331.png: only 6 after ratio test; skipping
# dino0331.png–dino0338.png: only 1 after ratio test; skipping
# dino0338.png–dino0337.png: 68/98 inliers, t = [-0.013, 0.598, -0.802]
# dino0337.png–dino0336.png: 55/79 inliers, t = [-0.008, 0.943, -0.332]
# dino0336.png–dino0335.png: only 6 after ratio test; skipping
# dino0335.png–dino0334.png: 56/81 inliers, t = [-0.014, -0.381, 0.925]
# dino0334.png–dino0333.png: 44/74 inliers, t = [-0.052, 0.417, -0.907]
# dino0333.png–dino0332.png: 62/86 inliers, t = [-0.018, 0.683, -0.730]
# dino0332.png–dino0339.png: only 1 after ratio test; skipping
# dino0339.png–dino0340.png: 78/117 inliers, t = [0.010, -0.109, 0.994]
# dino0340.png–dino0341.png: 70/105 inliers, t = [-0.019, 0.228, 0.974]
# dino0341.png–dino0342.png: 50/71 inliers, t = [0.036, 0.276, 0.961]
# dino0342.png–dino0348.png: only 2 after ratio test; skipping
# dino0348.png–dino0349.png: 48/66 inliers, t = [-0.037, -0.415, -0.909]
# dino0349.png–dino0350.png: 57/86 inliers, t = [-0.006, 0.362, -0.932]
# dino0350.png–dino0363.png: only 4 after ratio test; skipping
# dino0363.png–dino0362.png: 66/96 inliers, t = [0.057, 0.830, 0.555]
# dino0362.png–dino0361.png: 44/70 inliers, t = [-0.021, 0.264, 0.964]
# dino0361.png–dino0360.png: 34/47 inliers, t = [0.030, 0.126, 0.992]
# dino0360.png–dino0359.png: only 6 after ratio test; skipping
# dino0359.png–dino0358.png: 20/32 inliers, t = [-0.012, -0.366, -0.930]
# dino0358.png–dino0357.png: 42/59 inliers, t = [0.005, -0.900, -0.437]
# dino0357.png–dino0356.png: 63/87 inliers, t = [-0.023, -0.160, -0.987]
# dino0356.png–dino0355.png: 73/102 inliers, t = [-0.093, 0.849, -0.520]
# dino0355.png–dino0354.png: 72/116 inliers, t = [-0.015, 0.916, -0.401]
# dino0354.png–dino0353.png: 84/119 inliers, t = [-0.007, -0.500, -0.866]
# Done. Inlier visuals in ‘matches/’, summary in ‘pair_results.csv’.

# %%
import numpy as np
import cv2

# Assume these variables are defined already:
# K           : (3x3) calibration matrix
# F           : (3x3) fundamental matrix
# pts1, pts2  : (N×2) all matched points before RANSAC
# mask        : (N×1) inlier mask from findFundamentalMat

# 1) Extract only the inlier correspondences
mask_bool = mask.ravel().astype(bool)
pts1_in = pts1[mask_bool]
pts2_in = pts2[mask_bool]

# 2) Compute and fix the Essential matrix
E = K.T @ F @ K  # Essential matrix from calibration matrix and fundamental matrix
U, S, Vt = np.linalg.svd(E)

# Enforce singularity constraint (σ, σ, 0) on the Essential matrix
sigma = (S[0] + S[1]) / 2.0
E = U @ np.diag([sigma, sigma, 0]) @ Vt

# 3) Compute the four possible camera poses (R, t)
W = np.array([[0, -1,  0],
              [1,  0,  0],
              [0,  0,  1]])

# Create possible rotation matrices
R1 = U @ W @ Vt
R2 = U @ W.T @ Vt
t0 = U[:, 2]

# Ensure det(R) = +1 for valid rotation matrices
if np.linalg.det(R1) < 0: R1 *= -1
if np.linalg.det(R2) < 0: R2 *= -1

# List of 4 possible (R, t) hypotheses
candidates = [
    (R1,  t0),
    (R1, -t0),
    (R2,  t0),
    (R2, -t0),
]

# Helper function: triangulate points and count how many points have positive depth
def count_in_front(R, t, K, pts1, pts2):
    # Projection matrices for both cameras
    P1 = K @ np.hstack((np.eye(3), np.zeros((3, 1))))  # Camera 1: identity matrix for R, zero for t
    P2 = K @ np.hstack((R, t.reshape(3, 1)))  # Camera 2: [R|t] matrix
    
    # Convert points to normalized coordinates (undistorted)
    p1n = cv2.undistortPoints(pts1.reshape(-1, 1, 2), K, None)
    p2n = cv2.undistortPoints(pts2.reshape(-1, 1, 2), K, None)
    
    # Triangulate points (4xN homogeneous coordinates)
    X4 = cv2.triangulatePoints(P1, P2, p1n, p2n)
    X3 = (X4[:3] / X4[3]).T  # Convert to Euclidean coordinates (N×3)
    
    # Check depths in both camera frames
    z1 = X3[:, 2]  # Depth in the first camera (positive is in front of the camera)
    z2 = (R @ X3.T + t.reshape(3, 1))[2]  # Depth in the second camera
    
    # Count how many points have positive depth in both cameras
    return np.sum((z1 > 0) & (z2 > 0)), X3

# 4) Select the best pose based on the count of valid points
best_count = 0
for R_c, t_c in candidates:
    count, X3 = count_in_front(R_c, t_c, K, pts1_in, pts2_in)
    if count > best_count:
        best_count = count
        R_final, t_final, X_final = R_c, t_c, X3

print(f"→ Best pose has {best_count} points in front.")
print("Rotation (R_final):\n", R_final)
print("Translation (t_final):\n", t_final)

# 5) (optional) Convert 3D points to Euclidean coordinates
X3D = X_final  # Shape: (best_count x 3)
print("First few 3D points:\n", X3D[:5])
# Out:
# → Best pose has 84 points in front.
# Rotation (R_final):
#  [[ 0.99672795 -0.08008046  0.01097805]
#  [ 0.07973585  0.99639762  0.02887849]
#  [-0.01325111 -0.02790866  0.99952264]]
# Translation (t_final):
#  [-0.00692055 -0.49965152 -0.86619886]
# First few 3D points:
#  [[-2.376378  -1.3716363 23.33098  ]
#  [-2.376358  -1.3714566 23.331608 ]
#  [-2.3762972 -1.3714077 23.331572 ]
#  [-2.3762898 -1.3713775 23.3317   ]
#  [-2.3761408 -1.3717183 23.330488 ]]

# %%
import os
import cv2
import numpy as np

# --- 0) Reconstruct inlier_matches from the initial pair ---
mask_bool = mask.ravel().astype(bool)
inlier_matches = [m for m, valid in zip(good, mask_bool) if valid]

# --- 1) Convert homogeneous 4D points → Euclidean 3D ---
X3D = (X4_final[:3] / X4_final[3]).T   # shape: (M, 3)

# --- 2) Build a map: kp1 index → index in X3D ---
kp1_to_3d = { m.queryIdx: i for i, m in enumerate(inlier_matches) }

# Prepare storage for rotation and translation results
R_all, t_all = [], []

# --- 3) Loop over new images to perform incremental registration ---
for img_name in sorted_imgs[2:]:
    # Load new image & compute features
    img = cv2.imread(os.path.join(IMG_DIR, img_name), cv2.IMREAD_GRAYSCALE)
    kp2, des2 = sift.detectAndCompute(img, None)

    # Match back to the first image's descriptors using BFMatcher
    raw2 = bf.knnMatch(des2, des1, k=2)
    
    # Apply Lowe's ratio test to filter out bad matches
    good2 = [m for m, n in raw2 if m.distance < RATIO_THR * n.distance]

    # Collect 3D–2D correspondences
    obj_pts, img_pts = [], []
    for m in good2:
        if m.trainIdx in kp1_to_3d:
            obj_pts.append(X3D[kp1_to_3d[m.trainIdx]])
            img_pts.append(kp2[m.queryIdx].pt)

    obj_pts = np.array(obj_pts, dtype=np.float32)
    img_pts = np.array(img_pts, dtype=np.float32)

    # Skip frames with insufficient correspondences
    if len(obj_pts) < 6:
        print(f"{img_name}: only {len(obj_pts)} 3D–2D pairs, skipping")
        continue

    # --- 4) Solve PnP with RANSAC ---
    # Improve RANSAC parameters and reprojection error threshold for better accuracy
    success, rvec, tvec, inliers = cv2.solvePnPRansac(
        obj_pts, img_pts, K, None,
        reprojectionError=4.0,  # Reduced reprojection error threshold for better accuracy
        confidence=0.99,
        flags=cv2.SOLVEPNP_ITERATIVE
    )

    if not success:
        print(f"{img_name}: PnP failed")
        continue

    # --- 5) Convert rotation vector to matrix ---
    R, _ = cv2.Rodrigues(rvec)

    print(f"{img_name}:")
    print(" R =\n", R)
    print(" t =", tvec.ravel(), "\n")

    R_all.append(R)
    t_all.append(tvec)

# --- 6) Optional: Refine results (Bundle Adjustment or Pose Graph Optimization) ---
# If you want to further improve results, use bundle adjustment or pose graph optimization after this loop.
# Out:
# dino0047.png: only 0 3D–2D pairs, skipping
# dino0046.png: only 0 3D–2D pairs, skipping
# dino0045.png: only 1 3D–2D pairs, skipping
# dino0044.png: only 0 3D–2D pairs, skipping
# dino0043.png: only 0 3D–2D pairs, skipping
# dino0042.png: only 2 3D–2D pairs, skipping
# dino0041.png: only 2 3D–2D pairs, skipping
# dino0040.png: only 3 3D–2D pairs, skipping
# dino0039.png: only 0 3D–2D pairs, skipping
# dino0038.png: only 3 3D–2D pairs, skipping
# dino0037.png: PnP failed
# dino0036.png: PnP failed
# dino0035.png: PnP failed
# dino0034.png: PnP failed
# dino0033.png: PnP failed
# dino0032.png: PnP failed
# dino0031.png: PnP failed
# dino0030.png: PnP failed
# dino0006.png: only 1 3D–2D pairs, skipping
# dino0005.png: only 0 3D–2D pairs, skipping
# dino0004.png: only 1 3D–2D pairs, skipping
# dino0003.png: only 0 3D–2D pairs, skipping
# dino0002.png: only 1 3D–2D pairs, skipping
# dino0001.png: only 1 3D–2D pairs, skipping
# dino0050.png: only 1 3D–2D pairs, skipping
# dino0051.png: only 0 3D–2D pairs, skipping
# dino0052.png: only 0 3D–2D pairs, skipping
# dino0053.png: only 0 3D–2D pairs, skipping
# dino0054.png: only 0 3D–2D pairs, skipping
# dino0055.png: only 0 3D–2D pairs, skipping
# dino0056.png: only 0 3D–2D pairs, skipping
# dino0057.png: only 2 3D–2D pairs, skipping
# dino0058.png: only 2 3D–2D pairs, skipping
# dino0059.png: only 0 3D–2D pairs, skipping
# dino0060.png: only 2 3D–2D pairs, skipping
# dino0061.png: PnP failed
# dino0062.png: PnP failed
# dino0063.png: PnP failed
# dino0064.png: PnP failed
# dino0065.png: PnP failed
# dino0066.png: PnP failed
# dino0067.png: PnP failed
# dino0068.png: PnP failed
# dino0069.png: PnP failed
# dino0070.png: PnP failed
# dino0071.png: PnP failed
# dino0072.png: PnP failed
# dino0073.png: PnP failed
# dino0074.png: PnP failed
# dino0075.png: only 4 3D–2D pairs, skipping
# dino0090.png: only 2 3D–2D pairs, skipping
# dino0091.png: only 2 3D–2D pairs, skipping
# dino0092.png: only 1 3D–2D pairs, skipping
# dino0093.png: only 1 3D–2D pairs, skipping
# dino0094.png: only 1 3D–2D pairs, skipping
# dino0095.png: only 0 3D–2D pairs, skipping
# dino0096.png: only 1 3D–2D pairs, skipping
# dino0097.png: only 0 3D–2D pairs, skipping
# dino0145.png: only 0 3D–2D pairs, skipping
# dino0144.png: only 1 3D–2D pairs, skipping
# dino0143.png: only 0 3D–2D pairs, skipping
# dino0142.png: only 1 3D–2D pairs, skipping
# dino0141.png: only 2 3D–2D pairs, skipping
# dino0140.png: only 4 3D–2D pairs, skipping
# dino0139.png: only 1 3D–2D pairs, skipping
# dino0138.png: only 1 3D–2D pairs, skipping
# dino0137.png: only 2 3D–2D pairs, skipping
# dino0136.png: only 2 3D–2D pairs, skipping
# dino0135.png: only 2 3D–2D pairs, skipping
# dino0134.png: PnP failed
# dino0133.png: PnP failed
# dino0132.png: PnP failed
# dino0131.png: PnP failed
# dino0130.png: PnP failed
# dino0129.png: PnP failed
# dino0128.png: PnP failed
# dino0127.png: PnP failed
# dino0126.png: PnP failed
# dino0125.png: PnP failed
# dino0124.png: PnP failed
# dino0123.png: PnP failed
# dino0122.png: PnP failed
# dino0121.png: PnP failed
# dino0120.png: only 3 3D–2D pairs, skipping
# dino0119.png: only 4 3D–2D pairs, skipping
# dino0118.png: only 3 3D–2D pairs, skipping
# dino0117.png: only 3 3D–2D pairs, skipping
# dino0116.png: only 2 3D–2D pairs, skipping
# dino0112.png: only 3 3D–2D pairs, skipping
# dino0111.png: only 3 3D–2D pairs, skipping
# dino0110.png: only 2 3D–2D pairs, skipping
# dino0109.png: only 1 3D–2D pairs, skipping
# dino0106.png: only 3 3D–2D pairs, skipping
# dino0105.png: only 2 3D–2D pairs, skipping
# dino0104.png: only 1 3D–2D pairs, skipping
# dino0103.png: only 1 3D–2D pairs, skipping
# dino0102.png: only 1 3D–2D pairs, skipping
# dino0101.png: only 1 3D–2D pairs, skipping
# dino0100.png: only 1 3D–2D pairs, skipping
# dino0099.png: only 0 3D–2D pairs, skipping
# dino0098.png: only 1 3D–2D pairs, skipping
# dino0146.png: only 0 3D–2D pairs, skipping
# dino0147.png: only 1 3D–2D pairs, skipping
# dino0148.png: only 1 3D–2D pairs, skipping
# dino0149.png: only 1 3D–2D pairs, skipping
# dino0150.png: only 1 3D–2D pairs, skipping
# dino0151.png: only 1 3D–2D pairs, skipping
# dino0152.png: only 5 3D–2D pairs, skipping
# dino0157.png: PnP failed
# dino0158.png: PnP failed
# dino0159.png: PnP failed
# dino0160.png: PnP failed
# dino0161.png: only 5 3D–2D pairs, skipping
# dino0162.png: only 1 3D–2D pairs, skipping
# dino0163.png: only 0 3D–2D pairs, skipping
# dino0164.png: only 3 3D–2D pairs, skipping
# dino0165.png: only 2 3D–2D pairs, skipping
# dino0166.png: only 1 3D–2D pairs, skipping
# dino0167.png: only 4 3D–2D pairs, skipping
# dino0168.png: only 1 3D–2D pairs, skipping
# dino0169.png: only 1 3D–2D pairs, skipping
# dino0170.png: only 1 3D–2D pairs, skipping
# dino0171.png: only 2 3D–2D pairs, skipping
# dino0172.png: only 1 3D–2D pairs, skipping
# dino0173.png: only 1 3D–2D pairs, skipping
# dino0174.png: only 1 3D–2D pairs, skipping
# dino0175.png: only 0 3D–2D pairs, skipping
# dino0176.png: only 0 3D–2D pairs, skipping
# dino0177.png: only 0 3D–2D pairs, skipping
# dino0196.png: only 0 3D–2D pairs, skipping
# dino0195.png: only 0 3D–2D pairs, skipping
# dino0194.png: PnP failed
# dino0193.png: PnP failed
# dino0192.png: PnP failed
# dino0191.png: PnP failed
# dino0190.png: PnP failed
# dino0189.png: PnP failed
# dino0188.png: PnP failed
# dino0187.png: only 2 3D–2D pairs, skipping
# dino0186.png: only 0 3D–2D pairs, skipping
# dino0185.png: only 1 3D–2D pairs, skipping
# dino0184.png: only 0 3D–2D pairs, skipping
# dino0183.png: only 0 3D–2D pairs, skipping
# dino0182.png: only 2 3D–2D pairs, skipping
# dino0181.png: only 1 3D–2D pairs, skipping
# dino0180.png: only 3 3D–2D pairs, skipping
# dino0179.png: only 1 3D–2D pairs, skipping
# dino0178.png: only 2 3D–2D pairs, skipping
# dino0197.png: only 0 3D–2D pairs, skipping
# dino0198.png: only 0 3D–2D pairs, skipping
# dino0199.png: only 0 3D–2D pairs, skipping
# dino0200.png: only 0 3D–2D pairs, skipping
# dino0201.png: PnP failed
# dino0202.png: PnP failed
# dino0203.png: PnP failed
# dino0204.png: PnP failed
# dino0205.png: PnP failed
# dino0206.png: PnP failed
# dino0207.png: PnP failed
# dino0208.png: PnP failed
# dino0209.png: only 1 3D–2D pairs, skipping
# dino0210.png: only 3 3D–2D pairs, skipping
# dino0211.png: only 1 3D–2D pairs, skipping
# dino0212.png: only 1 3D–2D pairs, skipping
# dino0213.png: only 0 3D–2D pairs, skipping
# dino0214.png: only 0 3D–2D pairs, skipping
# dino0215.png: only 0 3D–2D pairs, skipping
# dino0216.png: only 2 3D–2D pairs, skipping
# dino0217.png: only 3 3D–2D pairs, skipping
# dino0218.png: only 1 3D–2D pairs, skipping
# dino0242.png: only 1 3D–2D pairs, skipping
# dino0241.png: only 1 3D–2D pairs, skipping
# dino0240.png: only 2 3D–2D pairs, skipping
# dino0239.png: PnP failed
# dino0238.png: PnP failed
# dino0237.png: PnP failed
# dino0236.png: PnP failed
# dino0235.png: PnP failed
# dino0234.png: PnP failed
# dino0233.png: PnP failed
# dino0232.png: PnP failed
# dino0231.png: only 4 3D–2D pairs, skipping
# dino0230.png: only 2 3D–2D pairs, skipping
# dino0229.png: only 3 3D–2D pairs, skipping
# dino0228.png: only 1 3D–2D pairs, skipping
# dino0227.png: only 1 3D–2D pairs, skipping
# dino0226.png: only 0 3D–2D pairs, skipping
# dino0225.png: only 0 3D–2D pairs, skipping
# dino0224.png: only 1 3D–2D pairs, skipping
# dino0223.png: only 1 3D–2D pairs, skipping
# dino0221.png: only 1 3D–2D pairs, skipping
# dino0220.png: only 1 3D–2D pairs, skipping
# dino0219.png: only 1 3D–2D pairs, skipping
# dino0243.png: only 1 3D–2D pairs, skipping
# dino0244.png: only 0 3D–2D pairs, skipping
# dino0245.png: only 1 3D–2D pairs, skipping
# dino0246.png: only 2 3D–2D pairs, skipping
# dino0247.png:
#  R =
#  [[ 0.95029962  0.29340848 -0.10412541]
#  [-0.26187762  0.93417919  0.24234139]
#  [ 0.16837681 -0.20302882  0.96458724]]
#  t = [  7.27349754  -7.19505628 -32.60138364]
#
# dino0248.png: PnP failed
# dino0249.png: PnP failed
# dino0250.png: PnP failed
# dino0251.png: PnP failed
# dino0252.png: PnP failed
# dino0253.png: only 5 3D–2D pairs, skipping
# dino0254.png: only 4 3D–2D pairs, skipping
# dino0255.png: only 2 3D–2D pairs, skipping
# dino0256.png: only 1 3D–2D pairs, skipping
# dino0257.png: only 0 3D–2D pairs, skipping
# dino0258.png: only 0 3D–2D pairs, skipping
# dino0259.png: only 0 3D–2D pairs, skipping
# dino0260.png: only 0 3D–2D pairs, skipping
# dino0261.png: only 1 3D–2D pairs, skipping
# dino0262.png: only 2 3D–2D pairs, skipping
# dino0263.png: only 1 3D–2D pairs, skipping
# dino0264.png: only 1 3D–2D pairs, skipping
# dino0265.png: only 2 3D–2D pairs, skipping
# dino0286.png: only 0 3D–2D pairs, skipping
# dino0285.png: only 0 3D–2D pairs, skipping
# dino0284.png: only 2 3D–2D pairs, skipping
# dino0283.png: PnP failed
# dino0282.png: only 4 3D–2D pairs, skipping
# dino0281.png: PnP failed
# dino0280.png: PnP failed
# dino0279.png: PnP failed
# dino0278.png: PnP failed
# dino0277.png: only 5 3D–2D pairs, skipping
# dino0276.png: only 3 3D–2D pairs, skipping
# dino0275.png: only 3 3D–2D pairs, skipping
# dino0274.png: only 2 3D–2D pairs, skipping
# dino0273.png: only 2 3D–2D pairs, skipping
# dino0272.png: only 2 3D–2D pairs, skipping
# dino0271.png: only 1 3D–2D pairs, skipping
# dino0270.png: only 0 3D–2D pairs, skipping
# dino0269.png: only 2 3D–2D pairs, skipping
# dino0268.png: only 1 3D–2D pairs, skipping
# dino0266.png: only 0 3D–2D pairs, skipping
# dino0287.png: only 3 3D–2D pairs, skipping
# dino0288.png: only 3 3D–2D pairs, skipping
# dino0289.png: only 5 3D–2D pairs, skipping
# dino0290.png: only 2 3D–2D pairs, skipping
# dino0291.png: PnP failed
# dino0292.png: PnP failed
# dino0293.png: only 4 3D–2D pairs, skipping
# dino0294.png: only 3 3D–2D pairs, skipping
# dino0295.png: only 2 3D–2D pairs, skipping
# dino0296.png: only 1 3D–2D pairs, skipping
# dino0297.png: only 4 3D–2D pairs, skipping
# dino0298.png: only 2 3D–2D pairs, skipping
# dino0299.png: only 1 3D–2D pairs, skipping
# dino0300.png: only 2 3D–2D pairs, skipping
# dino0301.png: only 2 3D–2D pairs, skipping
# dino0310.png: only 3 3D–2D pairs, skipping
# dino0309.png: only 2 3D–2D pairs, skipping
# dino0308.png: PnP failed
# dino0307.png: only 5 3D–2D pairs, skipping
# dino0306.png: only 5 3D–2D pairs, skipping
# dino0305.png: only 3 3D–2D pairs, skipping
# dino0304.png: only 0 3D–2D pairs, skipping
# dino0303.png: only 2 3D–2D pairs, skipping
# dino0302.png: only 2 3D–2D pairs, skipping
# dino0311.png: only 3 3D–2D pairs, skipping
# dino0312.png: only 4 3D–2D pairs, skipping
# dino0313.png: only 5 3D–2D pairs, skipping
# dino0314.png: only 3 3D–2D pairs, skipping
# dino0315.png: only 5 3D–2D pairs, skipping
# dino0316.png: only 4 3D–2D pairs, skipping
# dino0317.png: only 3 3D–2D pairs, skipping
# dino0320.png: only 1 3D–2D pairs, skipping
# dino0319.png: only 4 3D–2D pairs, skipping
# dino0318.png: PnP failed
# dino0321.png: only 5 3D–2D pairs, skipping
# dino0322.png: PnP failed
# dino0326.png: only 3 3D–2D pairs, skipping
# dino0325.png: PnP failed
# dino0324.png: only 5 3D–2D pairs, skipping
# dino0323.png: PnP failed
# dino0327.png: only 0 3D–2D pairs, skipping
# dino0328.png: only 3 3D–2D pairs, skipping
# dino0329.png: only 2 3D–2D pairs, skipping
# dino0331.png: only 3 3D–2D pairs, skipping
# dino0338.png: only 3 3D–2D pairs, skipping
# dino0337.png: only 4 3D–2D pairs, skipping
# dino0336.png: only 2 3D–2D pairs, skipping
# dino0335.png: only 1 3D–2D pairs, skipping
# dino0334.png: only 0 3D–2D pairs, skipping
# dino0333.png: only 0 3D–2D pairs, skipping
# dino0332.png: only 0 3D–2D pairs, skipping
# dino0339.png: only 3 3D–2D pairs, skipping
# dino0340.png: only 5 3D–2D pairs, skipping
# dino0341.png: only 1 3D–2D pairs, skipping
# dino0342.png: only 1 3D–2D pairs, skipping
# dino0348.png: only 2 3D–2D pairs, skipping
# dino0349.png: PnP failed
# dino0350.png: PnP failed
# dino0363.png: only 4 3D–2D pairs, skipping
# dino0362.png: only 2 3D–2D pairs, skipping
# dino0361.png: only 2 3D–2D pairs, skipping
# dino0360.png: only 2 3D–2D pairs, skipping
# dino0359.png: only 1 3D–2D pairs, skipping
# dino0358.png: only 3 3D–2D pairs, skipping
# dino0357.png: PnP failed
# dino0356.png: PnP failed
# dino0355.png: PnP failed
# dino0354.png: PnP failed
# dino0353.png: PnP failed

# %%
import os
import cv2
import numpy as np

# Initialize FLANN-based matcher for better feature matching
FLANN_INDEX_KDTREE = 1  # Flann index for KDTREE algorithm
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)  # or pass empty dictionary for default

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Initialize FLANN-based matcher
flann = cv2.FlannBasedMatcher(index_params, search_params)

# 0) Reconstruct inlier_matches from your initial pair
mask_bool = mask.ravel().astype(bool)
inlier_matches = [m for m, valid in zip(good, mask_bool) if valid]

# 1) Convert homogeneous 4D points → Euclidean 3D
X3D = (X4_final[:3] / X4_final[3]).T   # shape: (M,3)

# 2) Build a map: kp1 index → index in X3D
kp1_to_3d = { m.queryIdx: i for i, m in enumerate(inlier_matches) }

# Prepare storage for rotation and translation results
R_all, t_all = [], []

# 3) Loop over new images to perform incremental registration
for img_name in sorted_imgs[2:]:
    # Load new image & compute features
    img = cv2.imread(os.path.join(IMG_DIR, img_name), cv2.IMREAD_GRAYSCALE)

    # Check if the image is loaded successfully
    if img is None:
        print(f"{img_name}: Failed to load image.")
        continue

    kp2, des2 = sift.detectAndCompute(img, None)
    
    # Make sure descriptors are not None before proceeding
    if des2 is None:
        print(f"{img_name}: No keypoints or descriptors found.")
        continue

    # Match back to the first image's descriptors using FLANN-based matcher
    # Check if des1 (the descriptors from the reference image) are also not None
    if des1 is None:
        print(f"Reference image descriptors (des1) are empty. Skipping {img_name}.")
        continue

    # Perform FLANN-based matching with k=2 (for Lowe's ratio test)
    raw2 = flann.knnMatch(des2, des1, k=2)

    # Apply Lowe's ratio test to filter out bad matches (adjust threshold if necessary)
    good2 = [m for m, n in raw2 if m.distance < 0.6 * n.distance]  # use 0.6 threshold for stricter matching

    # Collect 3D–2D correspondences
    obj_pts, img_pts = [], []
    for m in good2:
        if m.trainIdx in kp1_to_3d:
            obj_pts.append(X3D[kp1_to_3d[m.trainIdx]])
            img_pts.append(kp2[m.queryIdx].pt)

    obj_pts = np.array(obj_pts, dtype=np.float32)
    img_pts = np.array(img_pts, dtype=np.float32)

    # Skip frames with insufficient correspondences
    if len(obj_pts) < 6:
        print(f"{img_name}: only {len(obj_pts)} 3D–2D pairs, skipping")
        continue

    # 4) Solve PnP with RANSAC
    success, rvec, tvec, inliers = cv2.solvePnPRansac(
        obj_pts, img_pts, K, None,
        reprojectionError=4.0,  # Lower reprojection error for higher accuracy
        confidence=0.99,
        flags=cv2.SOLVEPNP_ITERATIVE
    )

    if not success:
        print(f"{img_name}: PnP failed")
        continue

    # 5) Convert rotation vector to matrix
    R, _ = cv2.Rodrigues(rvec)

    print(f"{img_name}:")
    print(" R =\n", R)
    print(" t =", tvec.ravel(), "\n")

    R_all.append(R)
    t_all.append(tvec)

# Optionally, use Bundle Adjustment or Pose Graph Optimization to refine results after the loop
# For better results, bundle adjustment can optimize both 3D points and camera poses.
# Out:
# dino0047.png: only 0 3D–2D pairs, skipping
# dino0046.png: only 0 3D–2D pairs, skipping
# dino0045.png: only 1 3D–2D pairs, skipping
# dino0044.png: only 0 3D–2D pairs, skipping
# dino0043.png: only 0 3D–2D pairs, skipping
# dino0042.png: only 0 3D–2D pairs, skipping
# dino0041.png: only 0 3D–2D pairs, skipping
# dino0040.png: only 2 3D–2D pairs, skipping
# dino0039.png: only 0 3D–2D pairs, skipping
# dino0038.png: only 0 3D–2D pairs, skipping
# dino0037.png: only 1 3D–2D pairs, skipping
# dino0036.png: only 3 3D–2D pairs, skipping
# dino0035.png: PnP failed
# dino0034.png: PnP failed
# dino0033.png: PnP failed
# dino0032.png: PnP failed
# dino0031.png: PnP failed
# dino0030.png: only 3 3D–2D pairs, skipping
# dino0006.png: only 0 3D–2D pairs, skipping
# dino0005.png: only 0 3D–2D pairs, skipping
# dino0004.png: only 0 3D–2D pairs, skipping
# dino0003.png: only 0 3D–2D pairs, skipping
# dino0002.png: only 1 3D–2D pairs, skipping
# dino0001.png: only 0 3D–2D pairs, skipping
# dino0050.png: only 0 3D–2D pairs, skipping
# dino0051.png: only 0 3D–2D pairs, skipping
# dino0052.png: only 0 3D–2D pairs, skipping
# dino0053.png: only 0 3D–2D pairs, skipping
# dino0054.png: only 0 3D–2D pairs, skipping
# dino0055.png: only 0 3D–2D pairs, skipping
# dino0056.png: only 0 3D–2D pairs, skipping
# dino0057.png: only 0 3D–2D pairs, skipping
# dino0058.png: only 1 3D–2D pairs, skipping
# dino0059.png: only 0 3D–2D pairs, skipping
# dino0060.png: only 0 3D–2D pairs, skipping
# dino0061.png: only 3 3D–2D pairs, skipping
# dino0062.png: PnP failed
# dino0063.png: PnP failed
# dino0064.png: PnP failed
# dino0065.png: PnP failed
# dino0066.png: PnP failed
# dino0067.png: PnP failed
# dino0068.png: PnP failed
# dino0069.png: PnP failed
# dino0070.png: PnP failed
# dino0071.png: only 5 3D–2D pairs, skipping
# dino0072.png: only 5 3D–2D pairs, skipping
# dino0073.png: only 5 3D–2D pairs, skipping
# dino0074.png: only 5 3D–2D pairs, skipping
# dino0075.png: only 2 3D–2D pairs, skipping
# dino0090.png: only 1 3D–2D pairs, skipping
# dino0091.png: only 1 3D–2D pairs, skipping
# dino0092.png: only 0 3D–2D pairs, skipping
# dino0093.png: only 0 3D–2D pairs, skipping
# dino0094.png: only 0 3D–2D pairs, skipping
# dino0095.png: only 0 3D–2D pairs, skipping
# dino0096.png: only 0 3D–2D pairs, skipping
# dino0097.png: only 0 3D–2D pairs, skipping
# dino0145.png: only 0 3D–2D pairs, skipping
# dino0144.png: only 0 3D–2D pairs, skipping
# dino0143.png: only 1 3D–2D pairs, skipping
# dino0142.png: only 0 3D–2D pairs, skipping
# dino0141.png: only 1 3D–2D pairs, skipping
# dino0140.png: only 0 3D–2D pairs, skipping
# dino0139.png: only 0 3D–2D pairs, skipping
# dino0138.png: only 1 3D–2D pairs, skipping
# dino0137.png: only 0 3D–2D pairs, skipping
# dino0136.png: only 0 3D–2D pairs, skipping
# dino0135.png: only 0 3D–2D pairs, skipping
# dino0134.png: PnP failed
# dino0133.png: PnP failed
# dino0132.png: PnP failed
# dino0131.png: PnP failed
# dino0130.png: PnP failed
# dino0129.png: PnP failed
# dino0128.png: PnP failed
# dino0127.png: PnP failed
# dino0126.png: PnP failed
# dino0125.png: PnP failed
# dino0124.png: PnP failed
# dino0123.png: only 4 3D–2D pairs, skipping
# dino0122.png: only 4 3D–2D pairs, skipping
# dino0121.png: only 5 3D–2D pairs, skipping
# dino0120.png: only 1 3D–2D pairs, skipping
# dino0119.png: only 1 3D–2D pairs, skipping
# dino0118.png: only 0 3D–2D pairs, skipping
# dino0117.png: only 0 3D–2D pairs, skipping
# dino0116.png: only 2 3D–2D pairs, skipping
# dino0112.png: only 1 3D–2D pairs, skipping
# dino0111.png: only 1 3D–2D pairs, skipping
# dino0110.png: only 0 3D–2D pairs, skipping
# dino0109.png: only 0 3D–2D pairs, skipping
# dino0106.png: only 1 3D–2D pairs, skipping
# dino0105.png: only 1 3D–2D pairs, skipping
# dino0104.png: only 1 3D–2D pairs, skipping
# dino0103.png: only 0 3D–2D pairs, skipping
# dino0102.png: only 0 3D–2D pairs, skipping
# dino0101.png: only 0 3D–2D pairs, skipping
# dino0100.png: only 0 3D–2D pairs, skipping
# dino0099.png: only 0 3D–2D pairs, skipping
# dino0098.png: only 0 3D–2D pairs, skipping
# dino0146.png: only 0 3D–2D pairs, skipping
# dino0147.png: only 0 3D–2D pairs, skipping
# dino0148.png: only 0 3D–2D pairs, skipping
# dino0149.png: only 1 3D–2D pairs, skipping
# dino0150.png: only 0 3D–2D pairs, skipping
# dino0151.png: only 1 3D–2D pairs, skipping
# dino0152.png: only 0 3D–2D pairs, skipping
# dino0157.png: only 5 3D–2D pairs, skipping
# dino0158.png: only 2 3D–2D pairs, skipping
# dino0159.png: only 2 3D–2D pairs, skipping
# dino0160.png: only 3 3D–2D pairs, skipping
# dino0161.png: only 3 3D–2D pairs, skipping
# dino0162.png: only 0 3D–2D pairs, skipping
# dino0163.png: only 0 3D–2D pairs, skipping
# dino0164.png: only 1 3D–2D pairs, skipping
# dino0165.png: only 1 3D–2D pairs, skipping
# dino0166.png: only 0 3D–2D pairs, skipping
# dino0167.png: only 0 3D–2D pairs, skipping
# dino0168.png: only 0 3D–2D pairs, skipping
# dino0169.png: only 1 3D–2D pairs, skipping
# dino0170.png: only 1 3D–2D pairs, skipping
# dino0171.png: only 1 3D–2D pairs, skipping
# dino0172.png: only 0 3D–2D pairs, skipping
# dino0173.png: only 0 3D–2D pairs, skipping
# dino0174.png: only 0 3D–2D pairs, skipping
# dino0175.png: only 0 3D–2D pairs, skipping
# dino0176.png: only 0 3D–2D pairs, skipping
# dino0177.png: only 0 3D–2D pairs, skipping
# dino0196.png: only 0 3D–2D pairs, skipping
# dino0195.png: only 0 3D–2D pairs, skipping
# dino0194.png: PnP failed
# dino0193.png: PnP failed
# dino0192.png: PnP failed
# dino0191.png: PnP failed
# dino0190.png: PnP failed
# dino0189.png: only 1 3D–2D pairs, skipping
# dino0188.png: only 2 3D–2D pairs, skipping
# dino0187.png: only 1 3D–2D pairs, skipping
# dino0186.png: only 0 3D–2D pairs, skipping
# dino0185.png: only 0 3D–2D pairs, skipping
# dino0184.png: only 0 3D–2D pairs, skipping
# dino0183.png: only 0 3D–2D pairs, skipping
# dino0182.png: only 0 3D–2D pairs, skipping
# dino0181.png: only 1 3D–2D pairs, skipping
# dino0180.png: only 1 3D–2D pairs, skipping
# dino0179.png: only 1 3D–2D pairs, skipping
# dino0178.png: only 0 3D–2D pairs, skipping
# dino0197.png: only 0 3D–2D pairs, skipping
# dino0198.png: only 0 3D–2D pairs, skipping
# dino0199.png: only 0 3D–2D pairs, skipping
# dino0200.png: only 0 3D–2D pairs, skipping
# dino0201.png: PnP failed
# dino0202.png: PnP failed
# dino0203.png: PnP failed
# dino0204.png: PnP failed
# dino0205.png: PnP failed
# dino0206.png: PnP failed
# dino0207.png: only 4 3D–2D pairs, skipping
# dino0208.png: only 4 3D–2D pairs, skipping
# dino0209.png: only 1 3D–2D pairs, skipping
# dino0210.png: only 2 3D–2D pairs, skipping
# dino0211.png: only 0 3D–2D pairs, skipping
# dino0212.png: only 0 3D–2D pairs, skipping
# dino0213.png: only 0 3D–2D pairs, skipping
# dino0214.png: only 0 3D–2D pairs, skipping
# dino0215.png: only 0 3D–2D pairs, skipping
# dino0216.png: only 0 3D–2D pairs, skipping
# dino0217.png: only 0 3D–2D pairs, skipping
# dino0218.png: only 0 3D–2D pairs, skipping
# dino0242.png: only 0 3D–2D pairs, skipping
# dino0241.png: only 0 3D–2D pairs, skipping
# dino0240.png: only 0 3D–2D pairs, skipping
# dino0239.png: only 4 3D–2D pairs, skipping
# dino0238.png: PnP failed
# dino0237.png: PnP failed
# dino0236.png: PnP failed
# dino0235.png: PnP failed
# dino0234.png: PnP failed
# dino0233.png: PnP failed
# dino0232.png: only 3 3D–2D pairs, skipping
# dino0231.png: only 2 3D–2D pairs, skipping
# dino0230.png: only 1 3D–2D pairs, skipping
# dino0229.png: only 1 3D–2D pairs, skipping
# dino0228.png: only 0 3D–2D pairs, skipping
# dino0227.png: only 0 3D–2D pairs, skipping
# dino0226.png: only 0 3D–2D pairs, skipping
# dino0225.png: only 0 3D–2D pairs, skipping
# dino0224.png: only 0 3D–2D pairs, skipping
# dino0223.png: only 0 3D–2D pairs, skipping
# dino0221.png: only 0 3D–2D pairs, skipping
# dino0220.png: only 0 3D–2D pairs, skipping
# dino0219.png: only 0 3D–2D pairs, skipping
# dino0243.png: only 0 3D–2D pairs, skipping
# dino0244.png: only 0 3D–2D pairs, skipping
# dino0245.png: only 0 3D–2D pairs, skipping
# dino0246.png: only 1 3D–2D pairs, skipping
# dino0247.png: only 2 3D–2D pairs, skipping
# dino0248.png: PnP failed
# dino0249.png: PnP failed
# dino0250.png: PnP failed
# dino0251.png: PnP failed
# dino0252.png: PnP failed
# dino0253.png: only 2 3D–2D pairs, skipping
# dino0254.png: only 2 3D–2D pairs, skipping
# dino0255.png: only 1 3D–2D pairs, skipping
# dino0256.png: only 1 3D–2D pairs, skipping
# dino0257.png: only 0 3D–2D pairs, skipping
# dino0258.png: only 0 3D–2D pairs, skipping
# dino0259.png: only 0 3D–2D pairs, skipping
# dino0260.png: only 0 3D–2D pairs, skipping
# dino0261.png: only 0 3D–2D pairs, skipping
# dino0262.png: only 1 3D–2D pairs, skipping
# dino0263.png: only 1 3D–2D pairs, skipping
# dino0264.png: only 0 3D–2D pairs, skipping
# dino0265.png: only 0 3D–2D pairs, skipping
# dino0286.png: only 0 3D–2D pairs, skipping
# dino0285.png: only 0 3D–2D pairs, skipping
# dino0284.png: only 0 3D–2D pairs, skipping
# dino0283.png: only 2 3D–2D pairs, skipping
# dino0282.png: only 2 3D–2D pairs, skipping
# dino0281.png: only 2 3D–2D pairs, skipping
# dino0280.png: only 5 3D–2D pairs, skipping
# dino0279.png: PnP failed
# dino0278.png: only 2 3D–2D pairs, skipping
# dino0277.png: only 2 3D–2D pairs, skipping
# dino0276.png: only 1 3D–2D pairs, skipping
# dino0275.png: only 1 3D–2D pairs, skipping
# dino0274.png: only 0 3D–2D pairs, skipping
# dino0273.png: only 0 3D–2D pairs, skipping
# dino0272.png: only 0 3D–2D pairs, skipping
# dino0271.png: only 0 3D–2D pairs, skipping
# dino0270.png: only 0 3D–2D pairs, skipping
# dino0269.png: only 1 3D–2D pairs, skipping
# dino0268.png: only 1 3D–2D pairs, skipping
# dino0266.png: only 0 3D–2D pairs, skipping
# dino0287.png: only 0 3D–2D pairs, skipping
# dino0288.png: only 1 3D–2D pairs, skipping
# dino0289.png: only 2 3D–2D pairs, skipping
# dino0290.png: only 1 3D–2D pairs, skipping
# dino0291.png: only 4 3D–2D pairs, skipping
# dino0292.png: only 3 3D–2D pairs, skipping
# dino0293.png: only 2 3D–2D pairs, skipping
# dino0294.png: only 1 3D–2D pairs, skipping
# dino0295.png: only 0 3D–2D pairs, skipping
# dino0296.png: only 0 3D–2D pairs, skipping
# dino0297.png: only 0 3D–2D pairs, skipping
# dino0298.png: only 0 3D–2D pairs, skipping
# dino0299.png: only 0 3D–2D pairs, skipping
# dino0300.png: only 0 3D–2D pairs, skipping
# dino0301.png: only 0 3D–2D pairs, skipping
# dino0310.png: only 0 3D–2D pairs, skipping
# dino0309.png: only 2 3D–2D pairs, skipping
# dino0308.png: only 3 3D–2D pairs, skipping
# dino0307.png: only 1 3D–2D pairs, skipping
# dino0306.png: only 0 3D–2D pairs, skipping
# dino0305.png: only 0 3D–2D pairs, skipping
# dino0304.png: only 0 3D–2D pairs, skipping
# dino0303.png: only 0 3D–2D pairs, skipping
# dino0302.png: only 0 3D–2D pairs, skipping
# dino0311.png: only 1 3D–2D pairs, skipping
# dino0312.png: only 2 3D–2D pairs, skipping
# dino0313.png: only 1 3D–2D pairs, skipping
# dino0314.png: only 1 3D–2D pairs, skipping
# dino0315.png: only 1 3D–2D pairs, skipping
# dino0316.png: only 1 3D–2D pairs, skipping
# dino0317.png: only 1 3D–2D pairs, skipping
# dino0320.png: only 0 3D–2D pairs, skipping
# dino0319.png: only 0 3D–2D pairs, skipping
# dino0318.png: only 2 3D–2D pairs, skipping
# dino0321.png: only 2 3D–2D pairs, skipping
# dino0322.png: only 2 3D–2D pairs, skipping
# dino0326.png: only 0 3D–2D pairs, skipping
# dino0325.png: only 1 3D–2D pairs, skipping
# dino0324.png: only 2 3D–2D pairs, skipping
# dino0323.png: only 3 3D–2D pairs, skipping
# dino0327.png: only 0 3D–2D pairs, skipping
# dino0328.png: only 1 3D–2D pairs, skipping
# dino0329.png: only 1 3D–2D pairs, skipping
# dino0331.png: only 0 3D–2D pairs, skipping
# dino0338.png: only 1 3D–2D pairs, skipping
# dino0337.png: only 1 3D–2D pairs, skipping
# dino0336.png: only 1 3D–2D pairs, skipping
# dino0335.png: only 1 3D–2D pairs, skipping
# dino0334.png: only 0 3D–2D pairs, skipping
# dino0333.png: only 0 3D–2D pairs, skipping
# dino0332.png: only 0 3D–2D pairs, skipping
# dino0339.png: only 1 3D–2D pairs, skipping
# dino0340.png: only 4 3D–2D pairs, skipping
# dino0341.png: only 0 3D–2D pairs, skipping
# dino0342.png: only 1 3D–2D pairs, skipping
# dino0348.png: only 0 3D–2D pairs, skipping
# dino0349.png: only 3 3D–2D pairs, skipping
# dino0350.png: PnP failed
# dino0363.png: only 2 3D–2D pairs, skipping
# dino0362.png: only 1 3D–2D pairs, skipping
# dino0361.png: only 1 3D–2D pairs, skipping
# dino0360.png: only 1 3D–2D pairs, skipping
# dino0359.png: only 0 3D–2D pairs, skipping
# dino0358.png: only 1 3D–2D pairs, skipping
# dino0357.png: only 0 3D–2D pairs, skipping
# dino0356.png: PnP failed
# dino0355.png: PnP failed
# dino0354.png: PnP failed
# dino0353.png: PnP failed
